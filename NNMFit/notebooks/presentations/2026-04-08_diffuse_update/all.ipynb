# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from NNMFit.utilities import ScanHandler

# import plotting utils
sys.path.append( "/data/user/tvaneede/utils" )
from FlavourScansPlotting import get_contour_points, get_contour_points_angle

# import scanning points
from flavor_fracs import *
points = pd.read_pickle('/data/user/tvaneede/GlobalFit/custom_scan_flavor/default_custom_scan_points_flavor.pickle')
flavs = flavor_frac(np.asarray(points['astro_nue_ratio']),np.asarray(points['astro_nutau_ratio']))

# import plotting flavor triangle
sys.path.append( "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks" )
from plot_utils_triangle import *

# %%
dag_path        = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/dag_scans/flavor_globalfit"
hese_path       = f"{dag_path}/hese/"
globalfit_path  = f"{dag_path}/globalfit/"
# globalfit_hese_1st_path = f"{dag_path}/globalfit_hese/first_try"
# globalfit_hese_path = f"{dag_path}/globalfit_hese/datasets_v1/Poisson"
# globalfit_hese_flux_path = f"{dag_path}/globalfit_hese/flux_uncertainty_doug"

scan_dir_dict = {
    # # --- HESE spice ----
    # "hese_HESEBestfit_SPL_noinel_nosyst_Poisson_spice": f"{hese_path}/spice/hese_HESEBestfit_SPL_noinel_nosyst_Poisson",
    # "hese_SPL_noinel_nosyst_Poisson_spice": f"{hese_path}/spice/hese_SPL_noinel_nosyst_Poisson",

    # # --- HESE ----
    # "hese_HESEBestfit_SPL_noinel_nosyst_Poisson": f"{hese_path}/Poisson/hese_HESEBestfit_SPL_noinel_nosyst",
    # "hese_SPL_noinel_nosyst_Poisson":             f"{hese_path}/Poisson/hese_SPL_noinel_nosyst",
    # "hese_BPL_noinel_nosyst_Poisson":             f"{hese_path}/Poisson/hese_BPL_noinel_nosyst",

    # "hese_HESEBestfit_SPL_nosyst_Poisson": f"{hese_path}/Poisson/hese_HESEBestfit_SPL_nosyst",
    # "hese_SPL_nosyst_Poisson":             f"{hese_path}/Poisson/hese_SPL_nosyst",
    # "hese_BPL_nosyst_Poisson":             f"{hese_path}/Poisson/hese_BPL_nosyst",

    # "hese_HESEBestfit_SPL_noinel_nosyst_SAY": f"{hese_path}/SAY/hese_HESEBestfit_SPL_noinel_nosyst",
    # "hese_SPL_noinel_nosyst_SAY":             f"{hese_path}/SAY/hese_SPL_noinel_nosyst",
    # "hese_BPL_noinel_nosyst_SAY":             f"{hese_path}/SAY/hese_BPL_noinel_nosyst",

    # "hese_HESEBestfit_SPL_noineltrue_nosyst_SAY": f"{hese_path}/SAY/hese_HESEBestfit_SPL_noineltrue_nosyst",
    # "hese_SPL_noineltrue_nosyst_SAY":             f"{hese_path}/SAY/hese_SPL_noineltrue_nosyst",
    # "hese_BPL_noineltrue_nosyst_SAY":             f"{hese_path}/SAY/hese_BPL_noineltrue_nosyst",

    # "hese_HESEBestfit_SPL_nosyst_SAY": f"{hese_path}/SAY/hese_HESEBestfit_SPL_nosyst",
    # "hese_SPL_nosyst_SAY":             f"{hese_path}/SAY/hese_SPL_nosyst",
    # "hese_BPL_nosyst_SAY":             f"{hese_path}/SAY/hese_BPL_nosyst",

    # "hese_HESEBestfit_SPL_noinel_Poisson": f"{hese_path}/systematics/second_minimizer/hese_HESEBestfit_SPL_noinel",
    # "hese_SPL_noinel_Poisson":             f"{hese_path}/systematics/second_minimizer/hese_SPL_noinel",
    # "hese_BPL_noinel_Poisson":             f"{hese_path}/systematics/second_minimizer/hese_BPL_noinel",

    # "hese_HESEBestfit_SPL_noinel_Poisson_hybrid_minimizer": f"{hese_path}/systematics/second_minimizer/hese_HESEBestfit_SPL_noinel_hybrid_minimizer",
    # "hese_SPL_noinel_Poisson_hybrid_minimizer":             f"{hese_path}/systematics/second_minimizer/hese_SPL_noinel_hybrid_minimizer",
    # "hese_BPL_noinel_Poisson_hybrid_minimizer":             f"{hese_path}/systematics/second_minimizer/hese_BPL_noinel_hybrid_minimizer",

    # "hese_HESEBestfit_SPL_noinel_Poisson_hybrid_minimizer_fine": f"{hese_path}/systematics/second_minimizer/hese_HESEBestfit_SPL_noinel_hybrid_minimizer_fine",
    # "hese_SPL_noinel_Poisson_hybrid_minimizer_fine":             f"{hese_path}/systematics/second_minimizer/hese_SPL_noinel_hybrid_minimizer_fine",
    # "hese_BPL_noinel_Poisson_hybrid_minimizer_fine":             f"{hese_path}/systematics/second_minimizer/hese_BPL_noinel_hybrid_minimizer_fine",


    # --- Globalfit ---
    "globalfit_double_no_hybrid_SPL_noinel_nosyst":           f"{globalfit_path}/datasets_v1/Poisson/globalfit_double_no_hybrid_SPL_nosyst",
    "globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst":           f"{globalfit_path}/datasets_v1/Poisson/globalfit_double_no_hybrid_nohese_SPL_nosyst",

    "globalfit_double_no_hybrid_BPL_noinel_nosyst":           f"{globalfit_path}/datasets_v1/Poisson/globalfit_double_no_hybrid_BPL_nosyst",
    "globalfit_double_no_hybrid_nohese_BPL_noinel_nosyst":           f"{globalfit_path}/datasets_v1/Poisson/globalfit_double_no_hybrid_nohese_BPL_nosyst",

    "globalfit_double_no_hybrid_SPL_noinel":           f"{globalfit_path}/datasets_v1/Poisson/globalfit_double_no_hybrid_SPL",
    "globalfit_double_no_hybrid_nohese_SPL_noinel":           f"{globalfit_path}/datasets_v1/Poisson/globalfit_double_no_hybrid_nohese_SPL",

    "globalfit_double_no_hybrid_BPL_noinel":           f"{globalfit_path}/datasets_v1/Poisson/globalfit_double_no_hybrid_BPL",
    "globalfit_double_no_hybrid_nohese_BPL_noinel":           f"{globalfit_path}/datasets_v1/Poisson/globalfit_double_no_hybrid_nohese_BPL",

    # with inelasticity
    "globalfit_double_no_hybrid_SPL_nosyst":           f"{globalfit_path}/datasets_v2/Poisson/globalfit_double_no_hybrid_SPL_nosyst",
    "globalfit_double_no_hybrid_nohese_SPL_nosyst":           f"{globalfit_path}/datasets_v2/Poisson/globalfit_double_no_hybrid_nohese_SPL_nosyst",


    # # --- Globalfit+HESE ---
    # "globalfit_double_hese_SPL":             f"{globalfit_hese_1st_path}/globalfit_double_hese_SPL",
    # "globalfit_double_hese_BPL_range_philipp_strict":             f"{globalfit_hese_1st_path}/globalfit_double_hese_BPL_range_philipp_strict",
    # "globalfit_double_hese_BPL_range_philipp_strict_fine_center":             f"{globalfit_hese_1st_path}/globalfit_double_hese_BPL_range_philipp_strict_fine_center",

    # "globalfit_double_no_hybrid_hese_SPL_nosyst":             f"{globalfit_hese_path}/globalfit_double_no_hybrid_hese_SPL_nosyst",
    # "globalfit_double_no_hybrid_hese_BPL_nosyst":             f"{globalfit_hese_path}/globalfit_double_no_hybrid_hese_BPL_nosyst",

    # "globalfit_double_no_hybrid_hese_SPL":             f"{globalfit_hese_path}/globalfit_double_no_hybrid_hese_SPL",
    # "globalfit_double_no_hybrid_hese_BPL":             f"{globalfit_hese_path}/globalfit_double_no_hybrid_hese_BPL",

    # "globalfit_double_no_hybrid_hese_SPL_clean_hese_nosyst":             f"{globalfit_hese_path}/globalfit_double_no_hybrid_hese_SPL_clean_hese_nosyst",

    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL",
    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_gamma_high":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_gamma_high",
    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_gamma_low":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_gamma_low",
    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_phi_high":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_phi_high",
    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_phi_low":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_phi_low",

    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_fine_center":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_fine_center",
    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_gamma_high_fine_center":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_gamma_high_fine_center",
    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_gamma_low_fine_center":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_gamma_low_fine_center",
    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_phi_high_fine_center":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_phi_high_fine_center",
    # "globalfit_double_no_hybrid_hese_HESEBestfit_SPL_phi_low_fine_center":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_HESEBestfit_SPL_phi_low_fine_center",


    # "globalfit_double_no_hybrid_hese_BPL_range_philipp":             f"{globalfit_hese_flux_path}/globalfit_double_no_hybrid_hese_BPL",

}

# %%
plotting_path = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/presentations/2026-04-08_diffuse_update/all"
os.system(f"mkdir -p {plotting_path}")
# Out:
# 0

# %%
# load the data
N_grid = 40 # 20 was standard
drop_unsuccessful = False
scan_dict = {}
data = {}
for name, scan_dir in scan_dir_dict.items():
    print(name)
    print(scan_dir)
    scan_dict[name] = ScanHandler(scan_dir,dump=False,drop_unsuccessful=drop_unsuccessful)
    data[name] = {}
    if "newflavorparam" in name or "gf" in name:
        data[name]["ftau"],data[name]["fe"],data[name]["ts"],data[name]["ftau_grid"],data[name]["fe_grid"],data[name]["ts_grid"] = get_contour_points_angle(scan_dict,name)
    else:
        data[name]["ftau"],data[name]["fe"],data[name]["ts"],data[name]["ftau_grid"],data[name]["fe_grid"],data[name]["ts_grid"] = get_contour_points(scan_dict,name, N_grid=N_grid)
# Out:
# globalfit_double_no_hybrid_SPL_noinel_nosyst
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/dag_scans/flavor_globalfit/globalfit//datasets_v1/Poisson/globalfit_double_no_hybrid_SPL_nosyst
# removed stuff
# globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/dag_scans/flavor_globalfit/globalfit//datasets_v1/Poisson/globalfit_double_no_hybrid_nohese_SPL_nosyst
# removed stuff
# globalfit_double_no_hybrid_BPL_noinel_nosyst
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/dag_scans/flavor_globalfit/globalfit//datasets_v1/Poisson/globalfit_double_no_hybrid_BPL_nosyst
# removed stuff
# globalfit_double_no_hybrid_nohese_BPL_noinel_nosyst
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/dag_scans/flavor_globalfit/globalfit//datasets_v1/Poisson/globalfit_double_no_hybrid_nohese_BPL_nosyst
# removed stuff
# globalfit_double_no_hybrid_SPL_noinel
# ...

# %% [markdown]
# Comparing with and without systematics. Previously I made a mistake, I accidentally used the dataset where the overlap with the cascades was removed from HESE. That gave very unstable and poor results. So here I try again.

# %%
# compare_syst_HESEBestfit_hese
names = [
"hese_HESEBestfit_SPL_noinel_nosyst_Poisson",
"hese_HESEBestfit_SPL_noinel_Poisson"
]
labels = [
    "No systematics",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/compare_syst_HESEBestfit_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_HESEBestfit_SPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# Area ratio (hese_HESEBestfit_SPL_noinel_nosyst_Poisson / hese_HESEBestfit_SPL_noinel_nosyst_Poisson) at 68%: 1.0000
# Area ratio (hese_HESEBestfit_SPL_noinel_Poisson / hese_HESEBestfit_SPL_noinel_nosyst_Poisson) at 68%: 0.7767
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_syst_SPL_hese
names = [
"hese_SPL_noinel_nosyst_Poisson",
"hese_SPL_noinel_Poisson"
]
labels = [
    "No systematics",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/compare_syst_SPL_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_SPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_syst_BPL_hese
names = [
"hese_BPL_noinel_nosyst_Poisson",
"hese_BPL_noinel_Poisson"
]
labels = [
    "No systematics",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,BPL",
                  savepath = f"{plotting_path}/compare_syst_BPL_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_BPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %% [markdown]
# Now I am trying my hybrid minimizer

# %%
# compare_syst_HESEBestfit_hese_hybrid_minimizer
names = [
"hese_HESEBestfit_SPL_noinel_nosyst_Poisson",
"hese_HESEBestfit_SPL_noinel_Poisson_hybrid_minimizer"
]
labels = [
    "No systematics",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/compare_syst_HESEBestfit_hese_hybrid_minimizer.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_HESEBestfit_SPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# Area ratio (hese_HESEBestfit_SPL_noinel_nosyst_Poisson / hese_HESEBestfit_SPL_noinel_nosyst_Poisson) at 68%: 1.0000
# Area ratio (hese_HESEBestfit_SPL_noinel_Poisson_hybrid_minimizer / hese_HESEBestfit_SPL_noinel_nosyst_Poisson) at 68%: 0.9979
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
# ...

# %%
# compare_syst_hese_hybrid_minimizer
names = [
"hese_SPL_noinel_nosyst_Poisson",
"hese_SPL_noinel_Poisson_hybrid_minimizer"
]
labels = [
    "No systematics",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/compare_syst_SPL_hese_hybrid_minimizer.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_SPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_syst_hese_hybrid_minimizer
names = [
"hese_BPL_noinel_nosyst_Poisson",
"hese_BPL_noinel_Poisson_hybrid_minimizer"
]
labels = [
    "No systematics",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,BPL",
                  savepath = f"{plotting_path}/compare_syst_BPL_hese_hybrid_minimizer.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_BPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# Area ratio (hese_BPL_noinel_nosyst_Poisson / hese_BPL_noinel_nosyst_Poisson) at 68%: 1.0000
# Area ratio (hese_BPL_noinel_Poisson_hybrid_minimizer / hese_BPL_noinel_nosyst_Poisson) at 68%: 0.9986
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %% [markdown]
# Including the inelasticity again

# %%
# compare_inel_HESEBestfit_hese
names = [
"hese_HESEBestfit_SPL_noinel_nosyst_Poisson",
"hese_HESEBestfit_SPL_nosyst_Poisson",
]
labels = [
    "No inelasticity",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/compare_inel_HESEBestfit_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_HESEBestfit_SPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# Area ratio (hese_HESEBestfit_SPL_noinel_nosyst_Poisson / hese_HESEBestfit_SPL_noinel_nosyst_Poisson) at 68%: 1.0000
# Area ratio (hese_HESEBestfit_SPL_nosyst_Poisson / hese_HESEBestfit_SPL_noinel_nosyst_Poisson) at 68%: 1.0287
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_inel_SPL_hese
names = [
"hese_SPL_noinel_nosyst_Poisson",
"hese_SPL_nosyst_Poisson",
]
labels = [
    "No inelasticity",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/compare_inel_SPL_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_SPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_inel_BPL_hese
names = [
"hese_BPL_noinel_nosyst_Poisson",
"hese_BPL_nosyst_Poisson",
]
labels = [
    "No inelasticity",
    "With"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/compare_inel_BPL_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_BPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# Area ratio (hese_BPL_noinel_nosyst_Poisson / hese_BPL_noinel_nosyst_Poisson) at 68%: 1.0000
# Area ratio (hese_BPL_nosyst_Poisson / hese_BPL_noinel_nosyst_Poisson) at 68%: 1.0250
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %% [markdown]
# Now I also added the SAY likelihood. Quick comparison with SAY and Poisson

# %%
# compare_lik_HESEBestfit_hese
names = [
"hese_HESEBestfit_SPL_noinel_nosyst_Poisson",
"hese_HESEBestfit_SPL_noinel_nosyst_SAY",
]
labels = [
    "Poisson",
    "SAY"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/compare_lik_HESEBestfit_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_HESEBestfit_SPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# Area ratio (hese_HESEBestfit_SPL_noinel_nosyst_Poisson / hese_HESEBestfit_SPL_noinel_nosyst_Poisson) at 68%: 1.0000
# Area ratio (hese_HESEBestfit_SPL_noinel_nosyst_SAY / hese_HESEBestfit_SPL_noinel_nosyst_Poisson) at 68%: 1.0038
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_lik_SPL_hese
names = [
"hese_SPL_noinel_nosyst_Poisson",
"hese_SPL_noinel_nosyst_SAY",
]
labels = [
    "Poisson",
    "SAY"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/compare_lik_SPL_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_SPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_lik_BPL_hese
names = [
"hese_BPL_noinel_nosyst_Poisson",
"hese_BPL_noinel_nosyst_SAY",
]
labels = [
    "Poisson",
    "SAY"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,BPL",
                  savepath = f"{plotting_path}/compare_lik_BPL_hese.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_BPL_noinel_nosyst_Poisson", levels=["68%"] )
# Out:
# Area ratio (hese_BPL_noinel_nosyst_Poisson / hese_BPL_noinel_nosyst_Poisson) at 68%: 1.0000
# Area ratio (hese_BPL_noinel_nosyst_SAY / hese_BPL_noinel_nosyst_Poisson) at 68%: 1.0028
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %% [markdown]
# Now compare SAY with without inel

# %%
# compare_inel_HESEBestfit_hese_SAY
names = [
"hese_HESEBestfit_SPL_noinel_nosyst_SAY",
"hese_HESEBestfit_SPL_nosyst_SAY",
]
labels = [
    "With inelasticity",
    "Without"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/compare_inel_HESEBestfit_hese_SAY.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_HESEBestfit_SPL_noinel_nosyst_SAY", levels=["68%"] )
# Out:
# Area ratio (hese_HESEBestfit_SPL_noinel_nosyst_SAY / hese_HESEBestfit_SPL_noinel_nosyst_SAY) at 68%: 1.0000
# Area ratio (hese_HESEBestfit_SPL_nosyst_SAY / hese_HESEBestfit_SPL_noinel_nosyst_SAY) at 68%: 1.0284
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_inel_SPL_hese_SAY
names = [
"hese_SPL_noinel_nosyst_SAY",
"hese_SPL_nosyst_SAY",
]
labels = [
    "With inelasticity",
    "Without"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/compare_inel_SPL_hese_SAY.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_SPL_noinel_nosyst_SAY", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# Area ratio (hese_SPL_noinel_nosyst_SAY / hese_SPL_noinel_nosyst_SAY) at 68%: 1.0000
# Area ratio (hese_SPL_nosyst_SAY / hese_SPL_noinel_nosyst_SAY) at 68%: 1.0275
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_inel_BPL_hese_SAY
names = [
"hese_BPL_noinel_nosyst_SAY",
"hese_BPL_nosyst_SAY",
]
labels = [
    "With inelasticity",
    "Without"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,BPL",
                  savepath = f"{plotting_path}/compare_inel_BPL_hese_SAY.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_BPL_noinel_nosyst_SAY", levels=["68%"] )
# Out:
# Area ratio (hese_BPL_noinel_nosyst_SAY / hese_BPL_noinel_nosyst_SAY) at 68%: 1.0000
# Area ratio (hese_BPL_nosyst_SAY / hese_BPL_noinel_nosyst_SAY) at 68%: 1.0246
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %% [markdown]
# I made a mistake without inelasticity. It was removed from the astro component, but the atmospheric neutrinos still had it. Let's compare again, first just for SAY

# %%
# compare_ineltrue_HESEBestfit_hese_SAY
names = [
"hese_HESEBestfit_SPL_noineltrue_nosyst_SAY",
"hese_HESEBestfit_SPL_noinel_nosyst_SAY",
"hese_HESEBestfit_SPL_nosyst_SAY",
]
labels = [
    "With inelasticity",
    "Not in astro",
    "Without",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/compare_ineltrue_HESEBestfit_hese_SAY.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_HESEBestfit_SPL_noineltrue_nosyst_SAY", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# Area ratio (hese_HESEBestfit_SPL_noineltrue_nosyst_SAY / hese_HESEBestfit_SPL_noineltrue_nosyst_SAY) at 68%: 1.0000
# Area ratio (hese_HESEBestfit_SPL_noinel_nosyst_SAY / hese_HESEBestfit_SPL_noineltrue_nosyst_SAY) at 68%: 1.0074
# Area ratio (hese_HESEBestfit_SPL_nosyst_SAY / hese_HESEBestfit_SPL_noineltrue_nosyst_SAY) at 68%: 1.0320
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
# ...

# %%
# compare_ineltrue_SPL_hese_SAY
names = [
"hese_SPL_noineltrue_nosyst_SAY",
"hese_SPL_noinel_nosyst_SAY",
"hese_SPL_nosyst_SAY",
]
labels = [
    "With inelasticity",
    "Not in astro",
    "Without",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/compare_ineltrue_SPL_hese_SAY.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_SPL_noineltrue_nosyst_SAY", levels=["68%"] )
# Out:
# Area ratio (hese_SPL_noineltrue_nosyst_SAY / hese_SPL_noineltrue_nosyst_SAY) at 68%: 1.0000
# Area ratio (hese_SPL_noinel_nosyst_SAY / hese_SPL_noineltrue_nosyst_SAY) at 68%: 1.0134
# Area ratio (hese_SPL_nosyst_SAY / hese_SPL_noineltrue_nosyst_SAY) at 68%: 1.0329
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %%
# compare_ineltrue_BPL_hese_SAY
names = [
"hese_BPL_noineltrue_nosyst_SAY",
"hese_BPL_noinel_nosyst_SAY",
"hese_BPL_nosyst_SAY",
]
labels = [
    "With inelasticity",
    "Not in astro",
    "Without"
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%", "90%"],
                  title = r"HESE,BPL",
                  savepath = f"{plotting_path}/compare_ineltrue_BPL_hese_SAY.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_BPL_noineltrue_nosyst_SAY", levels=["68%"] )
# Out:
# Area ratio (hese_BPL_noineltrue_nosyst_SAY / hese_BPL_noineltrue_nosyst_SAY) at 68%: 1.0000
# Area ratio (hese_BPL_noinel_nosyst_SAY / hese_BPL_noineltrue_nosyst_SAY) at 68%: 1.0063
# Area ratio (hese_BPL_nosyst_SAY / hese_BPL_noineltrue_nosyst_SAY) at 68%: 1.0262
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %% [markdown]
# Now a quick check how my globalfits look, afterwards I want to add the inelasticity

# %%
# check_globalfit_no_inel_SPL
names = [
"globalfit_double_no_hybrid_SPL_noinel_nosyst",
"globalfit_double_no_hybrid_SPL_noinel",
"globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst",
"globalfit_double_no_hybrid_nohese_SPL_noinel",
]
labels = [
    "Globalfit",
    "With syst.",
    "No hese",
    "With syst.",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/check_globalfit_no_inel_SPL.png")

for name in names: compare_area( C, alt_key=name, base_key="globalfit_double_no_hybrid_SPL_nosyst", levels=["68%"] )
# Out:
# Area ratio (globalfit_double_no_hybrid_SPL_nosyst / globalfit_double_no_hybrid_SPL_nosyst) at 68%: 1.0000
# Area ratio (globalfit_double_no_hybrid_SPL / globalfit_double_no_hybrid_SPL_nosyst) at 68%: 1.1203
# Area ratio (globalfit_double_no_hybrid_nohese_SPL_nosyst / globalfit_double_no_hybrid_SPL_nosyst) at 68%: 2.2556
# Area ratio (globalfit_double_no_hybrid_nohese_SPL / globalfit_double_no_hybrid_SPL_nosyst) at 68%: 2.3498
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# ...

# %% [markdown]
# Adding the inelasticity

# %%
# compare_inel_globalfit_SPL_nosyst
names = [
"globalfit_double_no_hybrid_SPL_noinel_nosyst",
"globalfit_double_no_hybrid_SPL_nosyst",
"globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst",
"globalfit_double_no_hybrid_nohese_SPL_nosyst",
]
labels = [
    "Globalfit",
    "With inelasticity",
    "No hese",
    "With inelasticity",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"HESE,$\phi=1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/compare_inel_globalfit_SPL_nosyst.png")

for name in names: compare_area( C, alt_key=name, base_key="globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst", levels=["68%"] )
# Out:
# Area ratio (globalfit_double_no_hybrid_SPL_noinel_nosyst / globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst) at 68%: 0.4654
# Area ratio (globalfit_double_no_hybrid_SPL_nosyst / globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst) at 68%: 0.5770
# Area ratio (globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst / globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst) at 68%: 1.0000
# Area ratio (globalfit_double_no_hybrid_nohese_SPL_nosyst / globalfit_double_no_hybrid_nohese_SPL_noinel_nosyst) at 68%: 1.1416
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:160: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
# ...
