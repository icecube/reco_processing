# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os

# %%
sys.path.append("/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks")
from plot_utils import *

# %%
from NNMFit.utilities.readout_graphs import HistogramGraph
from NNMFit.core.analysis_config import AnalysisConfig

# %%
plotting_path = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/new_flavor_param/compare_BPL"
os.system(f"mkdir -p {plotting_path}")
# Out:
# 0

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/hese/hese_BPL.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/datasets_hese/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/bdt1_0.333333_bdt2_0.366667_length_10_fluxlessweight.cfg",
                               "override/binning/hese/10bdtprod_threshold_0.122.cfg",
                               "override/systematics/NoSystematics_hese.cfg",
                               ],
        override_components_files=["override/components/astro_BPL_no_inel.yaml"],
        override_parameters_files=None)
# build a histogram
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
input_variables = {
    r"Astro BPL" : {"astro_norm" : 1.77, "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Conv" : {"astro_norm" : 0.0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt" : {"astro_norm" : 0.0, "prompt_norm" : 1, "conv_norm" : 0},
    r"All" : {"astro_norm" : 1.77, "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 1, "conv_norm" : 1},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=None)
    break
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_Cascades

# %%
input_variables = {
    r"Astro NuAll" : {"astro_norm" : 1.77, "astro_nue_ratio" : 1, "astro_nutau_ratio" : 1,"gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro NuMu" : {"astro_norm" : 1.77, "astro_nue_ratio" : 0, "astro_nutau_ratio" : 0,"gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro NuMu+NuE" : {"astro_norm" : 1.77, "astro_nue_ratio" : 1, "astro_nutau_ratio" : 0,"gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro NuMu+NuTau" : {"astro_norm" : 1.77, "astro_nue_ratio" : 0, "astro_nutau_ratio" : 1,"gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=None)
    break
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_Cascades

# %%
import NNMFit
from NNMFit.utilities.readout_graphs import HistogramGraph
from NNMFit.core.analysis_config import AnalysisConfig

configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/hese/hese_BPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/datasets_hese/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/bdt1_0.333333_bdt2_0.366667_length_10_fluxlessweight.cfg",
                               "override/binning/hese/10bdtprod_threshold_0.122.cfg",
                               "override/systematics/NoSystematics_hese.cfg",
                               ],
        override_components_files=["override/components/astro_BPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)

# build a histogram
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
input_variables = {
    r"Astro BPL" : {"total_astro_norm" : 3*1.77, "a" : 0.4444444444, "b" : 0.0, "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Conv" : {"total_astro_norm" : 0.0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt" : {"total_astro_norm" : 0.0, "prompt_norm" : 1, "conv_norm" : 0},
    r"All" : {"total_astro_norm" : 3*1.77, "a" : 0.4444444444, "b" : 0.0, "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 1, "conv_norm" : 1},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=None)
    break
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_Cascades

# %%
input_variables = {
    r"Astro NuE" : {"total_astro_norm" : 1.77, "a" : flavor_ratios_to_angles(1,0,0)[0], "b" : flavor_ratios_to_angles(1,0,0)[1], "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro NuMu" : {"total_astro_norm" : 1.77, "a" : flavor_ratios_to_angles(0,1,0)[0], "b" : flavor_ratios_to_angles(0,1,0)[1], "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro NuTau" : {"total_astro_norm" : 1.77, "a" : flavor_ratios_to_angles(0,0,1)[0], "b" : flavor_ratios_to_angles(0,0,1)[1], "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro" : {"total_astro_norm" : 3*1.77, "a" : flavor_ratios_to_angles(1,1,1)[0], "b" : flavor_ratios_to_angles(1,1,1)[1], "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=None)
    break
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_Cascades

# %% [markdown]
# Lets check without angles

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/hese/hese_BPL.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/datasets_hese/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/bdt1_0.333333_bdt2_0.366667_length_10_fluxlessweight.cfg",
                               "override/binning/hese/10bdtprod_threshold_0.122.cfg",
                               "override/systematics/NoSystematics_hese.cfg",
                               ],
        override_components_files=["override/components/astro_BPL_flavorscaling_no_inel.yaml"],
        override_parameters_files=None)
# build a histogram
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
input_variables = {
    r"Astro BPL" : {"astro_norm" : 1.77, "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Conv" : {"astro_norm" : 0.0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt" : {"astro_norm" : 0.0, "prompt_norm" : 1, "conv_norm" : 0},
    r"All" : {"astro_norm" : 1.77, "gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 1, "conv_norm" : 1},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=None)
    break
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_Cascades

# %%
input_variables = {
    r"Astro NuAll" : {"astro_norm" : 1.77, "astro_nue_ratio" : 1, "astro_nutau_ratio" : 1,"gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro NuMu" : {"astro_norm" : 1.77, "astro_nue_ratio" : 0, "astro_nutau_ratio" : 0,"gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro NuMu+NuE" : {"astro_norm" : 1.77, "astro_nue_ratio" : 1, "astro_nutau_ratio" : 0,"gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro NuMu+NuTau" : {"astro_norm" : 1.77, "astro_nue_ratio" : 0, "astro_nutau_ratio" : 1,"gamma_1" : 1.31, "gamma_2" : 2.74, "e_break" : 4.39,"prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=None)
    break
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_Cascades
