# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LogLocator
import os

# %%
import NNMFit
from NNMFit.utilities.readout_graphs import HistogramGraph
from NNMFit.core.analysis_config import AnalysisConfig

# %%
import sys
sys.path.append("/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks")
from plot_utils import plot_histogram, plot_histogram_astro_flavor

# %%
plotting_path = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/compare_cascade/compare_zheyang_philipp"
os.system(f"mkdir -p {plotting_path}")
# Out:
# 0

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"

# %% [markdown]
# First zheyangs own parquet files. Probably some errors in the nfiles parameter

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main_globalfit.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/asimov_SAY_globalfit.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=None,
        override_components_files=None,
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# ...

# %%
plotting_path_histogram = f"{plotting_path}/cascade_zheyang"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"astro_norm" : 1.8, "prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
    plot_histogram_astro_flavor(hist_graph_hdl=hist_graph_hdl, det_config=det_config, ylog=True, 
                                gamma_astro = 2.52, astro_norm = 1.8,
                                savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks

# %% [markdown]
# My own parquet files, zheyangs bdt and cut threshold. Still with the mistake in nfiles. Almost identical to zheyang, except for 10% difference in double cascades.

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main_globalfit.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/asimov_SAY_globalfit.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/datasets_globalfit/datasets_22684_22692_train_zheyang_bdt1_0.45_bdt2_0.67.cfg"],
        override_components_files=None,
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# ...

# %%
plotting_path_histogram = f"{plotting_path}/datasets_22684_22692_train_zheyang_bdt1_0.45_bdt2_0.67"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"astro_norm" : 1.8, "prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
    plot_histogram_astro_flavor(hist_graph_hdl=hist_graph_hdl, det_config=det_config, ylog=True, 
                                gamma_astro = 2.52, astro_norm = 1.8,
                                savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks

# %% [markdown]
# Now I have a change in the number of nfiles. Zheyang had a mistake in not counting the empty files.
#
# Almost exactly the same as my previous iteration of these files. Still 10% more astro in double cascades.

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main_globalfit.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/asimov_SAY_globalfit.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/datasets_globalfit/datasets_22684_22692_v1_train_zheyang_bdt1_0.45_bdt2_0.67.cfg"],
        override_components_files=None,
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# ...

# %%
plotting_path_histogram = f"{plotting_path}/datasets_22684_22692_v1_train_zheyang_bdt1_0.45_bdt2_0.67"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"astro_norm" : 1.8, "prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
    plot_histogram_astro_flavor(hist_graph_hdl=hist_graph_hdl, det_config=det_config, ylog=True, 
                                gamma_astro = 2.52, astro_norm = 1.8,
                                savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks

# %% [markdown]
# Now with the other dataset, so I can match it in the globalfit
#
# Same rates, just some overfluctuation at high energy for the NuE contamination in the double cascades

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main_globalfit.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/asimov_SAY_globalfit.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/datasets_globalfit/datasets_22612_22644_train_zheyang_bdt1_0.45_bdt2_0.67.cfg"],
        override_components_files=None,
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# ...

# %%
plotting_path_histogram = f"{plotting_path}/datasets_22612_22644_train_zheyang_bdt1_0.45_bdt2_0.67"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"astro_norm" : 1.8, "prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
    plot_histogram_astro_flavor(hist_graph_hdl=hist_graph_hdl, det_config=det_config, ylog=True, 
                                gamma_astro = 2.52, astro_norm = 1.8,
                                savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks

# %% [markdown]
# Now lets remove the overlap with the HESE sample, for my model with econf, eventgen, rlogl milli, optimized thresholds for the bdt product analysis.
#
# We have 50 less astro events in the cascades, about -5%. HESE has O(100) events
#
# We still have 2.3/5.81 astro events left in double cascades

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main_globalfit.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/asimov_SAY_globalfit.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/datasets_globalfit/datasets_22612_22644_train_zheyang_bdt1_0.45_bdt2_0.67_noHESE.cfg"],
        override_components_files=None,
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# /mnt/ceph1-npx/user/tvaneede/software/py_venvs/py3-v4.2.1_nnmfit-v0.3.0/lib/python3.10/site-packages/NNMFit/core/analysis_config.py:726: DeprecationWarning: Old binning range format used. Please update you detector config.View the documentation for more information
#   warnings.warn(
# ...

# %%
plotting_path_histogram = f"{plotting_path}/datasets_22612_22644_train_zheyang_bdt1_0.45_bdt2_0.67_noHESE"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"astro_norm" : 1.8, "prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
    plot_histogram_astro_flavor(hist_graph_hdl=hist_graph_hdl, det_config=det_config, ylog=True, 
                                gamma_astro = 2.52, astro_norm = 1.8,
                                savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Cascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_DoubleCascades
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks
# IC86_pass2_SnowStorm_FTP_GlobalFit_Tracks

# %% [markdown]
# Lets do a quick cross check with Philipp's files.
#
# Quite significantly less events. For cascades
# - Conventional: 10454/11594 = 90%
# - Prompt: 67/110 = 33%
# - Astro: 1418/2203 = 64%
#
# And significantly more for tracks:
# - Conventional: 697399/441119 = 158%
# - Prompt: 2358/2206 = 106%
# - Astro: 6844/5043 = 136%
#
# It seems that the binning is different.
#
# For philipp cascades:
# reco_energy_binning = (2.8,7,22,log)
# reco_zenith_binning = (-1,1,2,cos)
#
# And for zheyang cascades:
# binning_range = [(2.6, 7, 23, log), (-1,1,4,cscd-cos)]
#
# For philipp tracks:
# reco_energy_binning = (2.5,7,46,log)
# reco_zenith_binning = (-1,0.0872,34,cos)
#
# And for zheyang tracks:
# binning_range = [(2.5,7,46,log), (-1,0.0872,34,cos)]
#
# TODO: I should also make sure to remove overlap from the track/cascade samples

# %%
config_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/reproduce_GP_globalfit"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{config_dir}/main_thijs.cfg",
        analysis_config_file = f"{config_dir}/analysis_configs/asimov/cascades/Poisson_thijs.yaml",
        override_dict=None,
        config_dir=config_dir,
        override_config_files=["override/thijs/no_syst.cfg","override/thijs/zheyang_livetime.cfg"],
        override_components_files=None,
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/reproduce_GP_globalfit"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"astro_norm" : 1.8, "prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
    plot_histogram_astro_flavor(hist_graph_hdl=hist_graph_hdl, det_config=det_config, ylog=True, 
                                gamma_astro = 2.52, astro_norm = 1.8,
                                savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils.py:198: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   axes[i].set_yscale("log") if ylog else 0
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_tracks
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils.py:198: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   axes[i].set_yscale("log") if ylog else 0

# %% [markdown]
# Lets try to overwite philipps dataframes in my globalfit framework.
