# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LogLocator
import os

# %%
import NNMFit
from NNMFit.utilities.readout_graphs import HistogramGraph
from NNMFit.core.analysis_config import AnalysisConfig

# %%
import sys
sys.path.append("/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks")
from plot_utils import plot_histogram

# %%
plotting_path = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/compare_cascade/compare_zheyang_round2"
os.system(f"mkdir -p {plotting_path}")
# Out:
# 0

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"

# %% [markdown]
# First the cascade file from Philipp

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_no_hybrid_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/philipp"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 1, "muon_norm" : 0, "muongun_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 1, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "gamma" : 2.52, "a" : 0.4444444444, "b" : 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": 1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": -1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 0.0, "b": 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_v2_cscd_cascade"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %% [markdown]
# Now lets see what happens when I reproduce it

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_no_hybrid_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg",
                               "override/datasets_GP_globalfit/reproduce_cscd_cascade.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
config_hdl.to_dict()['config']['IC86_pass2_SnowStorm_v2_cscd_cascade']
# Out:
# {'datasets_path': '/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/GP_globalfit/combined/SnowStorm_FTP_cscd_cascade/',
#  'baseline_dataset': '/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/GP_globalfit/combined/SnowStorm_FTP_cscd_cascade//dataset_IC86_pass2_SnowStorm_FTP_cscd_cascade_baseline.parquet',
#  'name': 'IC86_pass2_SnowStorm_v2_cscd_cascade',
#  'systematics': 'IC86_pass2_SnowStorm_v2_cscd_cascade_systematics',
#  'var_mapping': 'IC86_pass2_SnowStorm_v2_cscd_cascade_var_mapping',
#  'var_mapping_mc': 'IC86_pass2_SnowStorm_v2_cscd_cascade_var_mapping_mc',
#  'analysis_binning': 'IC86_pass2_SnowStorm_v2_cscd_cascade_2D_binning',
#  'data': '/data/ana/Diffuse/GlobalFit/NNMFit/datasets/data/data_cscd_cascade_FTP_Monopod_wCoords.parquet',
#  'livetime': '330315015.11',
#  'modification_hooks': '',
# ...

# %%
plotting_path_histogram = f"{plotting_path}/thijs"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 1, "muon_norm" : 0, "muongun_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 1, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "gamma" : 2.52, "a" : 0.4444444444, "b" : 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": 1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": -1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 0.0, "b": 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_v2_cscd_cascade"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %% [markdown]
# Now lets see what zheyang made of it

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_no_hybrid_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg",
                               "override/datasets_zheyang/zheyang_cascades_combined_copy_thijs.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/zheyang"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 1, "muon_norm" : 0, "muongun_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 1, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "gamma" : 2.52, "a" : 0.4444444444, "b" : 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": 1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": -1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 0.0, "b": 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_v2_cscd_cascade"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %% [markdown]
# Lets see how zheyang split them.
#
# They seem to add up perfectly.

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_no_hybrid_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg",
                               "override/datasets_zheyang/zheyang_cascades_double_cascade.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/zheyang_cascade_double_cascade"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 1, "muon_norm" : 0, "muongun_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 1, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "gamma" : 2.52, "a" : 0.4444444444, "b" : 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": 1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": -1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 0.0, "b": 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_v2_cscd_cascade", "IC86_pass2_SnowStorm_v2_cscd_cascade_double"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade_double

# %% [markdown]
# Now I reproduce those 2 datasets with zheyangs script
#
# Identical!

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_no_hybrid_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg",
                               "override/datasets_zheyang/zheyang_cascades_double_cascade_reproduce_22684_22692.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/zheyang_cascade_double_cascade_reproduce"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 1, "muon_norm" : 0, "muongun_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 1, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "gamma" : 2.52, "a" : 0.4444444444, "b" : 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": 1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": -1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 0.0, "b": 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_v2_cscd_cascade", "IC86_pass2_SnowStorm_v2_cscd_cascade_double"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade_double

# %% [markdown]
# Now I want to apply his script, and BDT, to the 22612-22646 dataset
#
# First the combined
#
# Conventional is 3% more, prompt 0.6% more, astro 0.3% more

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_no_hybrid_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg",
                               "override/datasets_zheyang/zheyang_cascades_combined_22612_22646.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/zheyang_22612_22646"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 1, "muon_norm" : 0, "muongun_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 1, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "gamma" : 2.52, "a" : 0.4444444444, "b" : 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": 1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": -1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 0.0, "b": 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_v2_cscd_cascade"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %% [markdown]
# Now I apply his BDT and script to the 22612-22646 datasets
#
# Changes with respect to the baseline (22684_22692) dataset
# - conventional: reduced by 0.5, within errors of baseline set
# - prompt: reduced by 0.9
# - astro: 1.019, within errors
# - nue: 1
# - numu: 0.53, outside errors of both datasets
# - nutau: 1.036, both within errors

# %%
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_no_hybrid_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg",
                               "override/datasets_zheyang/zheyang_cascades_double_cascade_reproduce_22612_22646.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/zheyang_cascade_double_cascade_reproduce_22612_22646"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 1, "muon_norm" : 0, "muongun_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "gamma" : 2.52, "prompt_norm" : 1, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "gamma" : 2.52, "a" : 0.4444444444, "b" : 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muon_norm" : 0, "muongun_norm" : 0},
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": 1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 1.0, "b": -1.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "gamma" : 2.52, "a" : 0.0, "b": 0.0, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_v2_cscd_cascade", "IC86_pass2_SnowStorm_v2_cscd_cascade_double"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade_double
