# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
sys.path.append("/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks")
from plot_utils import *

# %%
from NNMFit.utilities.readout_graphs import HistogramGraph
from NNMFit.core.analysis_config import AnalysisConfig

# %%
plotting_path = f"/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/review/combine_baseline_hese_desiati"
os.system(f"mkdir -p {plotting_path}")
# Out:
# 0

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/hese/hese_HESEBestfit_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics.cfg", 
                               "override/datasets_hese/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/bdt1_0.333333_bdt2_0.366667_length_10.cfg", 
                               "override/binning/hese/10bdtprod_threshold_0.122.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/baseline"
os.system(f"mkdir -p {plotting_path_histogram}")
input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 6.3699, "a" : 0.4444444444, "b" : 0.0 ,"prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-None.png")
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades

# %%
input_variables = {
    r"Astro $\nu_e$" : {"total_astro_norm" : 6.3699/3, "a" : 1.0, "b" : 1.0 ,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 6.3699/3, "a" : 1.0, "b" : -1.0 ,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 6.3699/3, "a" : 0.0, "b" : 0.0 ,"prompt_norm" : 0, "conv_norm" : 0},
}

for det_config in ["IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-None.png")
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades

# %% [markdown]
# Now lets the extra dataset, different set than training

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/hese/hese_HESEBestfit_SPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics.cfg", 
                               "override/datasets_hese/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/bdt1_0.333333_bdt2_0.366667_length_10_extraBaseline.cfg", 
                               "override/binning/hese/10bdtprod_threshold_0.122.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl_extra = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/extra"
os.system(f"mkdir -p {plotting_path_histogram}")
input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 6.3699, "a" : 0.4444444444, "b" : 0.0 ,"prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl_extra, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-None.png")
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades

# %%
input_variables = {
    r"Astro $\nu_e$" : {"total_astro_norm" : 6.3699/3, "a" : 1.0, "b" : 1.0 ,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 6.3699/3, "a" : 1.0, "b" : -1.0 ,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 6.3699/3, "a" : 0.0, "b" : 0.0 ,"prompt_norm" : 0, "conv_norm" : 0},
}

for det_config in ["IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades"]: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl_extra, det_config=det_config, input_variables = input_variables, ylog=None, 
                   savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-None.png")
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades

# %% [markdown]
# Lets make the plot paolo requested

# %%
def plot_histogram_double(hist_graph_hdl, det_config, input_variables, title=None, savepath=None,
                          hist_graph_hdl2=None, hdl1_label="hdl1", hdl2_label="hdl2"):

    print(det_config)
    binnings = hist_graph_hdl.get_binning(det_config=det_config)

    fig, axes = plt.subplots(3, 2, figsize=(10, 12), gridspec_kw={"height_ratios": [3, 3, 1]})
    axes_linear = axes[0]
    axes_log    = axes[1]
    axes_ratio  = axes[2]

    handlers = [(hist_graph_hdl, "solid"), (hist_graph_hdl2, "dashed")] if hist_graph_hdl2 is not None else [(hist_graph_hdl, "solid")]
    colors = [f"C{i}" for i in range(len(input_variables))]

    stored = {j: {} for j in range(len(input_variables))}

    for hdl_idx, (hdl, linestyle) in enumerate(handlers):
        for j, ((input_name, input_variable), color) in enumerate(zip(input_variables.items(), colors)):

            res = hdl.get_evaled_histogram(input_variables=input_variable, det_config=det_config, reshape=True)

            for i, (variable_name, binning) in enumerate(binnings.items()):

                hist = res["mu"].sum(axis=1 - i)
                yerror = np.sqrt(res["ssq"].sum(axis=1 - i))

                if i not in stored[j]:
                    stored[j][i] = {}
                stored[j][i][hdl_idx] = (hist, yerror, binning)

                label = f"{input_name}: {sum(hist):.2f}+-{sum(yerror):.2f}" if i == hdl_idx else None

                for ax_row in [axes_linear, axes_log]:
                    ax_row[i].stairs(hist, binning, label=label, linestyle=linestyle, color=color)
                    ax_row[i].fill_between(
                        binning,
                        np.r_[hist - yerror, (hist - yerror)[-1]],
                        np.r_[hist + yerror, (hist + yerror)[-1]],
                        step="post", alpha=0.2, color=color
                    )
                    ax_row[i].set_xlim(min(binning), max(binning))
                    ax_row[i].set_ylabel(f"Rate / {hdl.get_livetime(det_config) / (3600 * 24 * 365.25):.2f} yr")
                    if "energy" in variable_name or "length" in variable_name:
                        ax_row[i].set_xscale("log")
                        axes_ratio[i].set_xscale("log")

                axes_log[i].set_yscale("log")

    # Legends
    legend_titles = [hdl1_label, hdl2_label] if hist_graph_hdl2 is not None else [hdl1_label]
    for i, legend_title in enumerate(legend_titles):
        axes_linear[i].legend(title=legend_title, fontsize=8, title_fontsize=9)
        axes_log[i].legend(title=legend_title, fontsize=8, title_fontsize=9)

    # Ratio plots
    for j, ((input_name, input_variable), color) in enumerate(zip(input_variables.items(), colors)):
        for i, (variable_name, binning) in enumerate(binnings.items()):
            if hist_graph_hdl2 is not None and 0 in stored[j][i] and 1 in stored[j][i]:
                hist1, yerr1, binning = stored[j][i][0]
                hist2, yerr2, _ = stored[j][i][1]

                with np.errstate(divide="ignore", invalid="ignore"):
                    ratio = np.where(hist2 != 0, hist1 / hist2, np.nan)
                    ratio_err = np.where(
                        hist2 != 0,
                        ratio * np.sqrt((yerr1 / np.where(hist1 != 0, hist1, np.nan)) ** 2 +
                                        (yerr2 / np.where(hist2 != 0, hist2, np.nan)) ** 2),
                        np.nan
                    )

                axes_ratio[i].stairs(ratio, binning, color=color, linestyle="solid")
                axes_ratio[i].fill_between(
                    binning,
                    np.r_[ratio - ratio_err, (ratio - ratio_err)[-1]],
                    np.r_[ratio + ratio_err, (ratio + ratio_err)[-1]],
                    step="post", alpha=0.2, color=color
                )

    for i, (variable_name, binning) in enumerate(binnings.items()):
        axes_ratio[i].axhline(1.0, color="gray", linestyle="--", linewidth=0.8, zorder=0)
        axes_ratio[i].set_xlabel(x_labels[variable_name])
        axes_ratio[i].set_ylabel(f"{hdl1_label} / {hdl2_label}")
        axes_ratio[i].set_xlim(min(binning), max(binning))

    # Remove x tick labels from linear and log rows
    for ax in [*axes_linear, *axes_log]:
        ax.set_xticklabels([])

    plt.suptitle(det_config if not title else title)
    plt.tight_layout()
    if savepath:
        plt.savefig(savepath)
    plt.show()

# %%
plotting_path_histogram = f"{plotting_path}/overlay"
os.system(f"mkdir -p {plotting_path_histogram}")
input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "prompt_norm" : 0, "conv_norm" : 1},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "prompt_norm" : 1, "conv_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 6.3699, "a" : 0.4444444444, "b" : 0.0 ,"prompt_norm" : 0, "conv_norm" : 0},
}
for det_config in ["IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades"]: 
    plot_histogram_double(hist_graph_hdl=hist_graph_hdl, 
                          hist_graph_hdl2=hist_graph_hdl_extra,
                          hdl1_label="Train", hdl2_label="Extra",
                          det_config=det_config, input_variables = input_variables, 
                          savepath=f"{plotting_path_histogram}/{det_config}_ylog-None.png")
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades

# %%
input_variables = {
    r"Astro $\nu_e$" : {"total_astro_norm" : 6.3699/3, "a" : 1.0, "b" : 1.0 ,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 6.3699/3, "a" : 1.0, "b" : -1.0 ,"prompt_norm" : 0, "conv_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 6.3699/3, "a" : 0.0, "b" : 0.0 ,"prompt_norm" : 0, "conv_norm" : 0},
}

for det_config in ["IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades"]: 
    plot_histogram_double(hist_graph_hdl=hist_graph_hdl, 
                          hist_graph_hdl2=hist_graph_hdl_extra,
                          hdl1_label="Train", hdl2_label="Extra",
                          det_config=det_config, input_variables = input_variables, 
                          savepath=f"{plotting_path_histogram}/flavor_astro_{det_config}_ylog-None.png")
# Out:
# IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades

# %% [markdown]
# Now lets do the combined

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/asimov_SAY_HESEBestfit.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics.cfg", 
                               "override/datasets_hese/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/bdt1_0.333333_bdt2_0.366667_length_10_combinedBaseline.cfg", 
                               "override/binning/hese/10bdtprod_threshold_0.122.cfg"],
        override_components_files=None,
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
