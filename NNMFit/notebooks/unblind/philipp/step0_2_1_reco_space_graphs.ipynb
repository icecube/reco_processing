# %%
import os
import subprocess

configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
output_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs"
python = "/home/pfuerst/venvs/NNMFit0.5_py3.11/bin/python"
script = "/home/pfuerst/venvs/NNMFit0.5_py3.11/bin/calculate_graph.py"

os.makedirs(output_dir, exist_ok=True)

# %%
DEFAULT_OVERRIDE_CONFIGS = [
    "override/binning/hese/10bdtprod_threshold_0.122.cfg",
    "override/livetime/hese_livetime_13yr.cfg",
    "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg",
]
DEFAULT_OVERRIDE_COMPONENTS = [
    "override/components/astro_SPL_no_inel_no_flavor.yaml",
    "override/muon/muontemplate_hese_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml",
]

CONFIGS = [
    # {
    #     "name": "hese_spectrum_bestfit_13year_round3",
    #     "analysis_config": "analysis_configs/data/debug_unblind/hese_spectrum_bestfit_13year_round3.yaml",
    #     "override_configs": ["override/systematics/Snowstorm_Gradients_hese_HESEBestfit_SPL_wpriors.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
    #     "override_components": DEFAULT_OVERRIDE_COMPONENTS,
    #     "override_parameters": None,
    # },
    # {
    #     "name": "hese_spectrum_bestfit_13year_round3_NoSystematics",
    #     "analysis_config": "analysis_configs/data/debug_unblind/hese_spectrum_bestfit_13year_round3.yaml",
    #     "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
    #     "override_components": DEFAULT_OVERRIDE_COMPONENTS,
    #     "override_parameters": None,
    # },
    # {
    #     "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics",
    #     "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
    #     "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
    #     "override_components": DEFAULT_OVERRIDE_COMPONENTS,
    #     "override_parameters": None,
    # },
    # {
    #     "name": "hese_seed_neha_NoSystematics",
    #     "analysis_config": "analysis_configs/data/debug_unblind/hese_seed_neha.yaml",
    #     "override_configs": ["override/datasets_hese/spice.cfg", "override/systematics/NoSystematics_hese.cfg"],
    #     "override_components": ["override/components/astro_SPL.yaml"],
    #     "override_parameters": None,
    # },
    # {
    #     "name": "FTP_data_sim_seed_neha_WithFlavor_NoSystematics",
    #     "analysis_config": "analysis_configs/data/debug_unblind/hese_seed_neha.yaml",
    #     "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
    #     "override_components": ["override/components/astro_SPL.yaml",
    #                             "override/muon/muontemplate_hese_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml"],
    #     "override_parameters": None,
    # },

    # BDT variables
    # {
    #     "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_bdt1_bdt2",
    #     "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
    #     "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
    #                          "override/livetime/hese_livetime_13yr.cfg",
    #                          "override/binning/hese/combined/bdt1_bdt2_10bins.cfg",
    #                          "override/binning/hese/combined/cut_energy.cfg",
    #                          "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
    #     "override_components": DEFAULT_OVERRIDE_COMPONENTS,
    #     "override_parameters": None,
    # },


    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_len_easym",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
                             "override/livetime/hese_livetime_13yr.cfg",
                             "override/binning/hese/combined/Taupede_Distance_Taupede_Asymmetry_10bins.cfg",
                             "override/binning/hese/combined/cut_energy.cfg",
                             "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
        "override_components": ["override/components/astro_SPL_no_inel_no_flavor.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_e1_e2",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
                             "override/livetime/hese_livetime_13yr.cfg",
                             "override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins.cfg",
                             "override/binning/hese/combined/cut_energy.cfg",
                             "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
        "override_components": ["override/components/astro_SPL_no_inel_no_flavor.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_mono_energy_zenith",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
                             "override/livetime/hese_livetime_13yr.cfg",
                             "override/binning/hese/combined/MonopodFit_iMIGRAD_PPB0_energy_cscdSBU_MonopodFit4_noDC_zenith_10bins.cfg",
                             "override/binning/hese/combined/cut_energy.cfg",
                             "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
        "override_components": ["override/components/astro_SPL_no_inel_no_flavor.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_mono_delay_qmax",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
                             "override/livetime/hese_livetime_13yr.cfg",
                             "override/binning/hese/combined/MonopodFit_iMIGRAD_PPB0_Delay_ice_CVStatistics_q_max_doms_10bins.cfg",
                             "override/binning/hese/combined/cut_energy.cfg",
                             "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
        "override_components": ["override/components/astro_SPL_no_inel_no_flavor.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_vtxdist_qtot",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
                             "override/livetime/hese_livetime_13yr.cfg",
                             "override/binning/hese/combined/cscdSBU_VertexRecoDist_CscdLLh_cscdSBU_Qtot_HLC_log_10bins.cfg",
                             "override/binning/hese/combined/cut_energy.cfg",
                             "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
        "override_components": ["override/components/astro_SPL_no_inel_no_flavor.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_taumono_econf",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
                             "override/livetime/hese_livetime_13yr.cfg",
                             "override/binning/hese/combined/TauMonoDiff_rlogl_econfinement_10bins.cfg",
                             "override/binning/hese/combined/cut_energy.cfg",
                             "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
        "override_components": ["override/components/astro_SPL_no_inel_no_flavor.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_tauspe_taumilli",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
                             "override/livetime/hese_livetime_13yr.cfg",
                             "override/binning/hese/combined/TauSPEMilliDiff_rlogl_TauMonoMilliDiff_rlogl_10bins.cfg",
                             "override/binning/hese/combined/cut_energy.cfg",
                             "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
        "override_components": ["override/components/astro_SPL_no_inel_no_flavor.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics_evtgen_recoeratio",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg",
                             "override/livetime/hese_livetime_13yr.cfg",
                             "override/binning/hese/combined/EventGeneratorDC_Thijs_length_RecoERatio_EventGeneratorDC_Max_10bins.cfg",
                             "override/binning/hese/combined/cut_energy.cfg",
                             "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg"],
        "override_components": ["override/components/astro_SPL_no_inel_no_flavor.yaml"],
        "override_parameters": None,
    },

]

# %%
from histogram_maker import *
from do_scan_analysis import *

# %%
for cfg in CONFIGS:
    name = cfg["name"]
    outpath = os.path.join(output_dir, name)
    outfile = os.path.join(outpath, "Precalculated_Graph.pickle")
    os.makedirs(outpath, exist_ok=True)

    NNMFit_config_options = {
        "init_method": "from_configs",
        "main_config": os.path.join(configs_dir, "main.cfg"),
        "analysis_config": os.path.join(configs_dir, cfg["analysis_config"]),
        "config_dir": configs_dir,
        "override_configs": cfg["override_configs"],
        "override_components": cfg["override_components"],
        "override_parameters": cfg["override_parameters"],
    }

    cmd = [
        python, script,
        "--main_config", os.path.join(configs_dir, "main.cfg"),
        "--analysis_config", os.path.join(configs_dir, cfg["analysis_config"]),
        "--config_dir", configs_dir,
        "--override_configs", *cfg["override_configs"],
        "--override_components", *cfg["override_components"],
        "-o", outfile,
    ]
    if cfg["override_parameters"]:
        cmd += ["--override_parameters", *cfg["override_parameters"]]

    result = subprocess.run(cmd, capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print(result.stderr)

    make_histogram_from_variables(NNMFit_config_options=NNMFit_config_options, out_file=f"{outpath}/MC_Histogram.pickle")
    generate_data_hist(scan_path=outpath)
# Out:
# Called with:
# main_config             : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/main.cfg
# analysis_config         : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml
# config_dir              : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/
# override_configs        : ['override/systematics/NoSystematics_hese_combined.cfg', 'override/livetime/hese_livetime_13yr.cfg', 'override/binning/hese/combined/Taupede_Distance_Taupede_Asymmetry_10bins.cfg', 'override/binning/hese/combined/cut_energy.cfg', 'override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg']
# override_components     : ['override/components/astro_SPL_no_inel_no_flavor.yaml']
# override_parameters     : None
# config_infile           : None
# precalculated_graph     : None
# ...

# %%
CONFIGS_MC = [
    # hese_spectrum_bestfit_13year_round3 (total + components)
    {
        "name": "hese_spectrum_bestfit_13year_round3",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": DEFAULT_OVERRIDE_COMPONENTS,
        "override_parameters": None,
    },
    {
        "name": "hese_spectrum_bestfit_13year_round3_Astro",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_spectrum_bestfit_13year_round3_Astro.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": DEFAULT_OVERRIDE_COMPONENTS,
        "override_parameters": None,
    },
    {
        "name": "hese_spectrum_bestfit_13year_round3_Conv",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_spectrum_bestfit_13year_round3_Conv.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": DEFAULT_OVERRIDE_COMPONENTS,
        "override_parameters": None,
    },
    {
        "name": "hese_spectrum_bestfit_13year_round3_Muon",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_spectrum_bestfit_13year_round3_Muon.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": DEFAULT_OVERRIDE_COMPONENTS,
        "override_parameters": None,
    },
    # hese_seed_neha (total + components)
    {
        "name": "hese_seed_neha",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_seed_neha.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": ["override/components/astro_SPL.yaml",
                                "override/muon/muontemplate_hese_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_seed_neha_Astro",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_seed_neha_Astro.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": ["override/components/astro_SPL.yaml",
                                "override/muon/muontemplate_hese_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_seed_neha_Conv",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_seed_neha_Conv.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": ["override/components/astro_SPL.yaml",
                                "override/muon/muontemplate_hese_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml"],
        "override_parameters": None,
    },
    {
        "name": "hese_seed_neha_Muon",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_seed_neha_Muon.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": ["override/components/astro_SPL.yaml",
                                "override/muon/muontemplate_hese_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml"],
        "override_parameters": None,
    },
]

# %%
for cfg in CONFIGS_MC:
    name = cfg["name"]
    outpath = os.path.join(output_dir, name)
    os.makedirs(outpath, exist_ok=True)

    NNMFit_config_options = {
        "init_method": "from_configs",
        "main_config": os.path.join(configs_dir, "main.cfg"),
        "analysis_config": os.path.join(configs_dir, cfg["analysis_config"]),
        "config_dir": configs_dir,
        "override_configs": cfg["override_configs"],
        "override_components": cfg["override_components"],
        "override_parameters": cfg["override_parameters"],
    }

    make_histogram_from_variables(NNMFit_config_options=NNMFit_config_options, out_file=f"{outpath}/MC_Histogram.pickle")
