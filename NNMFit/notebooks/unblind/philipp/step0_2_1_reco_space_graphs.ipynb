# %%
import os
import subprocess

configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
output_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs"
python = "/home/pfuerst/venvs/NNMFit0.5_py3.11/bin/python"
script = "/home/pfuerst/venvs/NNMFit0.5_py3.11/bin/calculate_graph.py"

os.makedirs(output_dir, exist_ok=True)

# %%
DEFAULT_OVERRIDE_CONFIGS = [
    "override/binning/hese/10bdtprod_threshold_0.122.cfg",
    "override/livetime/hese_livetime_13yr.cfg",
    "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg",
]
DEFAULT_OVERRIDE_COMPONENTS = [
    "override/components/astro_SPL_no_inel_no_flavor.yaml",
    "override/muon/muontemplate_hese_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml",
]

CONFIGS = []

# %%
# best fit
CONFIGS += [
    {
        "name": "hese_spectrum_bestfit_13year_round3",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/Snowstorm_Gradients_hese_HESEBestfit_SPL_wpriors.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": DEFAULT_OVERRIDE_COMPONENTS,
        "override_parameters": None,
    },
    {
        "name": "hese_spectrum_bestfit_13year_round3_NoSystematics",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": DEFAULT_OVERRIDE_COMPONENTS,
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/hese_combined/unblind_bdt/Snowstorm_Gradients_hese_combined_HESEBestfit_SPL_wpriors_energy_zenith.cfg", 
                             "override/muon/hese_combined_include_muon_template.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": DEFAULT_OVERRIDE_COMPONENTS,
        "override_parameters": None,
    },
    {
        "name": "hese_combined_spectrum_bestfit_13year_round3_NoSystematics",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese_combined.cfg", 
                             "override/muon/hese_combined_include_muon_template.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": DEFAULT_OVERRIDE_COMPONENTS,
        "override_parameters": None,
    }
    ]

# %%
# spice
CONFIGS += [
    {
        "name": "hese_seed_neha_NoSystematics",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_seed_neha.yaml",
        "override_configs": ["override/datasets_hese/spice.cfg", "override/systematics/NoSystematics_hese.cfg"],
        "override_components": ["override/components/astro_SPL.yaml"],
        "override_parameters": None,
    },
    {
        "name": "FTP_data_sim_seed_neha_WithFlavor_NoSystematics",
        "analysis_config": "analysis_configs/data/debug_unblind/hese_seed_neha.yaml",
        "override_configs": ["override/systematics/NoSystematics_hese.cfg"] + DEFAULT_OVERRIDE_CONFIGS,
        "override_components": ["override/components/astro_SPL.yaml",
                                "override/muon/muontemplate_hese_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml"],
        "override_parameters": None,
    }]

# %%
# BDT variables
_NO_FLAVOR = ["override/components/astro_SPL_no_inel_no_flavor.yaml"] # just means no muon

_BDT_VARS = [
    # ("bdt1_bdt2",          "bdt1_bdt2_10bins.cfg",                                                            DEFAULT_OVERRIDE_COMPONENTS),
    # ("energy_length_analysis",          "energy_length_analysis.cfg",                                   _NO_FLAVOR),
    # ("len_easym",          "Taupede_Distance_Taupede_Asymmetry_10bins.cfg",                                   _NO_FLAVOR),
    # ("e1_e2",              "Taupede1_Particles_energy_Taupede2_Particles_energy_10bins.cfg",                  _NO_FLAVOR),
    ("e1_e2_zoom",              "Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg",                  _NO_FLAVOR),
    # ("mono_energy_zenith", "MonopodFit_iMIGRAD_PPB0_energy_cscdSBU_MonopodFit4_noDC_zenith_10bins.cfg",      _NO_FLAVOR),
    # ("mono_delay_qmax",    "MonopodFit_iMIGRAD_PPB0_Delay_ice_CVStatistics_q_max_doms_10bins.cfg",           _NO_FLAVOR),
    ("mono_delay_qmax_zoom",    "MonopodFit_iMIGRAD_PPB0_Delay_ice_CVStatistics_q_max_doms_10bins_zoom.cfg",           _NO_FLAVOR),
    # ("vtxdist_qtot",       "cscdSBU_VertexRecoDist_CscdLLh_cscdSBU_Qtot_HLC_log_10bins.cfg",                _NO_FLAVOR),
    ("vtxdist_qtot_zoom",       "cscdSBU_VertexRecoDist_CscdLLh_cscdSBU_Qtot_HLC_log_10bins_zoom.cfg",                _NO_FLAVOR),
    # ("taumono_econf",      "TauMonoDiff_rlogl_econfinement_10bins.cfg",                                       _NO_FLAVOR),
    ("taumono_econf_zoom",      "TauMonoDiff_rlogl_econfinement_10bins_zoom.cfg",                                       _NO_FLAVOR),
    # ("tauspe_taumilli",    "TauSPEMilliDiff_rlogl_TauMonoMilliDiff_rlogl_10bins.cfg",                        _NO_FLAVOR),
    ("tauspe_taumilli_zoom",    "TauSPEMilliDiff_rlogl_TauMonoMilliDiff_rlogl_10bins_zoom.cfg",                        _NO_FLAVOR),
    # ("evtgen_recoeratio",  "EventGeneratorDC_Thijs_length_RecoERatio_EventGeneratorDC_Max_10bins.cfg",        _NO_FLAVOR),
    ("evtgen_recoeratio_zoom",  "EventGeneratorDC_Thijs_length_RecoERatio_EventGeneratorDC_Max_10bins_zoom.cfg",        _NO_FLAVOR),
]

_bdt_configs = []
for var, binning, components in _BDT_VARS:
    for syst_cfg, name_suffix in [
        ("override/systematics/NoSystematics_hese_combined.cfg", f"NoSystematics_{var}"),
        (f"override/systematics/hese_combined/unblind_bdt/Snowstorm_Gradients_hese_combined_HESEBestfit_SPL_wpriors_{var}.cfg", var),
    ]:
        _bdt_configs.append({
            "name": f"hese_combined_spectrum_bestfit_13year_round3_{name_suffix}",
            "analysis_config": "analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml",
            "override_configs": [
                syst_cfg,
                "override/livetime/hese_livetime_13yr.cfg",
                f"override/binning/hese/combined/{binning}",
                "override/binning/hese/combined/cut_energy.cfg",
                "override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg",
            ],
            "override_components": components,
            "override_parameters": None,
        })
CONFIGS += _bdt_configs

# %%
from histogram_maker import *
from do_scan_analysis import *

# %%
for cfg in CONFIGS:
    name = cfg["name"]
    outpath = os.path.join(output_dir, name)
    outfile = os.path.join(outpath, "Precalculated_Graph.pickle")
    os.makedirs(outpath, exist_ok=True)

    NNMFit_config_options = {
        "init_method": "from_configs",
        "main_config": os.path.join(configs_dir, "main.cfg"),
        "analysis_config": os.path.join(configs_dir, cfg["analysis_config"]),
        "config_dir": configs_dir,
        "override_configs": cfg["override_configs"],
        "override_components": cfg["override_components"],
        "override_parameters": cfg["override_parameters"],
    }

    cmd = [
        python, script,
        "--main_config", os.path.join(configs_dir, "main.cfg"),
        "--analysis_config", os.path.join(configs_dir, cfg["analysis_config"]),
        "--config_dir", configs_dir,
        "--override_configs", *cfg["override_configs"],
        "--override_components", *cfg["override_components"],
        "-o", outfile,
    ]
    if cfg["override_parameters"]:
        cmd += ["--override_parameters", *cfg["override_parameters"]]

    result = subprocess.run(cmd, capture_output=True, text=True)
    print(result.stdout)
    if result.stderr:
        print(result.stderr)

    make_histogram_from_variables(NNMFit_config_options=NNMFit_config_options, out_file=f"{outpath}/MC_Histogram.pickle")
    generate_data_hist(scan_path=outpath)

    for component in ["Astro", "Conv", "Muon"]:
        NNMFit_config_options["analysis_config"] = os.path.join(configs_dir, cfg["analysis_config"].replace(".yaml", f"_{component}.yaml"))
        print(10*"-", "Separate component", component)
        print(NNMFit_config_options["analysis_config"])
        make_histogram_from_variables(NNMFit_config_options=NNMFit_config_options, out_file=f"{outpath}/MC_Histogram_{component}.pickle")
# Out:
# Called with:
# main_config             : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/main.cfg
# analysis_config         : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml
# config_dir              : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/
# override_configs        : ['override/systematics/NoSystematics_hese_combined.cfg', 'override/livetime/hese_livetime_13yr.cfg', 'override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg', 'override/binning/hese/combined/cut_energy.cfg', 'override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg']
# override_components     : ['override/components/astro_SPL_no_inel_no_flavor.yaml']
# override_parameters     : None
# config_infile           : None
# precalculated_graph     : None
# outfile                 : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_NoSystematics_e1_e2_zoom/Precalculated_Graph.pickle
# init_method             : from_configs
#
# INFO:NNMFit.core.analysis_config: Loading main config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/main.cfg (2026-06-09 10:29:41; analysis_config.py:179)
# DEBUG:NNMFit.core.analysis_config: Keys loaded: ['DEFAULT', 'main', 'minimizer_settings'] (2026-06-09 10:29:41; analysis_config.py:181)
# INFO:NNMFit.core.analysis_config: Overriding config with: ['override/systematics/NoSystematics_hese_combined.cfg', 'override/livetime/hese_livetime_13yr.cfg', 'override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg', 'override/binning/hese/combined/cut_energy.cfg', 'override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg'] (2026-06-09 10:29:41; analysis_config.py:362)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/systematics/NoSystematics_hese_combined.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/livetime/hese_livetime_13yr.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/binning/hese/combined/cut_energy.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Reading detector configs ['IC86_pass2_SnowStorm_FTP_HESE_Combined'] from dir /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/ (2026-06-09 10:29:41; analysis_config.py:328)
# INFO:NNMFit.core.analysis_config: Reading components settings from: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/components.yaml (2026-06-09 10:29:41; analysis_config.py:253)
# INFO:NNMFit.core.analysis_config: Overriding components settings (2026-06-09 10:29:41; analysis_config.py:257)
# INFO:NNMFit.core.analysis_config: Overriding settings with: override/components/astro_SPL_no_inel_no_flavor.yaml (2026-06-09 10:29:41; analysis_config.py:310)
# INFO:NNMFit.core.analysis_config: Reading parameter settings from: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/parameters.yaml (2026-06-09 10:29:41; analysis_config.py:264)
# DEBUG:NNMFit.core.analysis_config: Reading config for conventional_globalfit component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter conv_norm for conventional_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for conventional_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for conventional_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_h for conventional_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_w for conventional_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_z for conventional_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_y for conventional_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter conv_norm for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_h for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_w for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_z for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_y for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter effective_veto for conventional_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for prompt_globalfit component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter prompt_norm for prompt_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for prompt_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for prompt_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for prompt_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter prompt_norm for prompt_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for prompt_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for prompt_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter effective_veto for prompt_veto_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for muontemplate_cascade_globalfit component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter muongun_norm_cascade for muontemplate_cascade_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for muontemplate_track_globalfit component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter muon_norm for muontemplate_track_globalfit component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for astro component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter astro_norm for astro component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter gamma_astro for astro component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for conventional_hese component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter conv_norm for conventional_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for conventional_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for conventional_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_h for conventional_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_w for conventional_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_z for conventional_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_y for conventional_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for prompt_hese component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter prompt_norm for prompt_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for prompt_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for prompt_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for muontemplate_hese component (2026-06-09 10:29:41; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter muongun_norm for muontemplate_hese component (2026-06-09 10:29:41; analysis_config.py:282)
# INFO:NNMFit.core.analysis_config: Reading detector systematics config: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/SnowStorm_systematics.cfg (2026-06-09 10:29:41; analysis_config.py:343)
# INFO:NNMFit.core.analysis_config: Overriding config with: ['override/systematics/NoSystematics_hese_combined.cfg', 'override/livetime/hese_livetime_13yr.cfg', 'override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg', 'override/binning/hese/combined/cut_energy.cfg', 'override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg'] (2026-06-09 10:29:41; analysis_config.py:362)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/systematics/NoSystematics_hese_combined.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/livetime/hese_livetime_13yr.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/binning/hese/combined/cut_energy.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg (2026-06-09 10:29:41; analysis_config.py:367)
# DEBUG:NNMFit.core.loader: Loading the binning and mask for IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; loader.py:43)
# DEBUG:NNMFit.binning.rectangular_binning: binning variables: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:29:41; rectangular_binning.py:105)
# DEBUG:NNMFit.binning.rectangular_binning: Histogram of det. conf. IC86_pass2_SnowStorm_FTP_HESE_Combined has 2 dimensions  (2026-06-09 10:29:41; rectangular_binning.py:271)
# DEBUG:NNMFit.binning.rectangular_binning: binning variables: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:29:41; rectangular_binning.py:105)
# DEBUG:NNMFit.binning.rectangular_binning: Histogram of det. conf. IC86_pass2_SnowStorm_FTP_HESE_Combined has 2 dimensions  (2026-06-09 10:29:41; rectangular_binning.py:271)
# INFO:NNMFit.core.nnm_fitter: Analysis type set to data (2026-06-09 10:29:41; nnm_fitter.py:87)
# INFO:NNMFit.core.parameter_settings: Skipping component(s) : ['muontemplate_cascade_globalfit', 'conventional_globalfit', 'conventional_veto_globalfit', 'prompt_globalfit', 'prompt_veto_globalfit', 'muon', 'muontemplate_track_globalfit', 'muontemplate_hese'] in weight calculation for det conf IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; parameter_settings.py:122)
# DEBUG:NNMFit.core.parameter_settings: Skipping conventional_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping conventional_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_cascade_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_track_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_hese component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:41; parameter_settings.py:159)
# WARNING:NNMFit.parameters.delta_gamma: Did not specify a reference energy for DeltaGamma. Are you sure you want to calculate it as median from the baseline weights directly? This might not include PassingFractions or similar corrections and can result in different reference energies usedfor different detector configurations sharing this parameter. (2026-06-09 10:29:41; delta_gamma.py:34)
# WARNING:NNMFit.parameters.delta_gamma: Did not specify a reference energy for DeltaGamma. Are you sure you want to calculate it as median from the baseline weights directly? This might not include PassingFractions or similar corrections and can result in different reference energies usedfor different detector configurations sharing this parameter. (2026-06-09 10:29:41; delta_gamma.py:34)
# INFO:NNMFit.core.loader: Using dataset: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/dataset_IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight.parquet (2026-06-09 10:29:41; loader.py:104)
# DEBUG:NNMFit.data_handling.data_handler: Reading file /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/dataset_IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight.parquet (2026-06-09 10:29:41; data_handler.py:32)
# DEBUG:NNMFit.data_handling.data_handler: Ignoring all keys except for None (2026-06-09 10:29:41; data_handler.py:33)
# INFO:NNMFit.data_handling.data_handler: Setting analysis vars: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:29:46; data_handler.py:130)
# WARNING:NNMFit.core.mask_handler: Please specify, which masks should be applied by adding 'apply_standard_mask = True/False' to your detector config. For now the mask will be applied, but this default will be deprecated in the future. (2026-06-09 10:29:46; mask_handler.py:65)
# DEBUG:NNMFit.core.mask_handler: Found 588203 events in binning (2026-06-09 10:29:46; mask_handler.py:156)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '>', '59979.10762555'] (2026-06-09 10:29:46; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '>', '59979.10762555'], 650915 events remain. (2026-06-09 10:29:46; mask_handler.py:249)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '<', '12589254.11794166'] (2026-06-09 10:29:46; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '<', '12589254.11794166'], 579216 events remain. (2026-06-09 10:29:46; mask_handler.py:249)
# WARNING:NNMFit.core.mask_handler: 'additional_mask' will be deprecated in the future. Use 'custom_mask' instead (2026-06-09 10:29:46; mask_handler.py:86)
# DEBUG:NNMFit.data_handling.data_handler: Applying mask, new n_events: 539743 (2026-06-09 10:29:46; data_handler.py:175)
# DEBUG:NNMFit.core.weight_builder: Memory footprint of shared data variables: 0.05227818340063095 (2026-06-09 10:29:46; weight_builder.py:204)
# INFO:NNMFit.core.parameter_settings: Collecting histogram parameters (2026-06-09 10:29:46; parameter_settings.py:55)
# INFO:NNMFit.core.parameter_settings: Skipping component(s) : ['muontemplate_cascade_globalfit', 'conventional_globalfit', 'conventional_veto_globalfit', 'prompt_globalfit', 'prompt_veto_globalfit', 'muon', 'muontemplate_track_globalfit', 'muontemplate_hese'] for det conf IC86_pass2_SnowStorm_FTP_HESE_Combined in histogram parameters (2026-06-09 10:29:46; parameter_settings.py:64)
# DEBUG:NNMFit.core.parameter_settings: Skipping conventional_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:46; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping conventional_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:46; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:46; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:46; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_cascade_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:46; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_track_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:46; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_hese component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:46; parameter_settings.py:86)
# INFO:NNMFit.core.histogram_builder: Building histogram graph for IC86_pass2_SnowStorm_FTP_HESE_Combined ... (2026-06-09 10:29:46; histogram_builder.py:407)
# INFO:NNMFit.core.weight_builder: Building weight graph for IC86_pass2_SnowStorm_FTP_HESE_Combined ... (2026-06-09 10:29:46; weight_builder.py:266)
# INFO:NNMFit.core.weight_builder: Creating graph for flux astro (2026-06-09 10:29:46; weight_builder.py:224)
# DEBUG:NNMFit.fluxes.Flux: Added parameter astro_norm to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter gamma_astro to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.core.weight_builder: Multiplying flux astro by livetime (414033153.63 seconds) (2026-06-09 10:29:46; weight_builder.py:248)
# INFO:NNMFit.core.weight_builder: Creating graph for flux conventional_hese (2026-06-09 10:29:46; weight_builder.py:224)
# DEBUG:NNMFit.fluxes.Flux: Added parameter conv_norm to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter delta_gamma to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter CR_grad to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter barr_h to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter barr_w to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter barr_z to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter barr_y to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.core.weight_builder: Multiplying flux conventional_hese by livetime (414033153.63 seconds) (2026-06-09 10:29:46; weight_builder.py:248)
# INFO:NNMFit.core.weight_builder: Creating graph for flux prompt_hese (2026-06-09 10:29:46; weight_builder.py:224)
# DEBUG:NNMFit.fluxes.Flux: Added parameter prompt_norm to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter delta_gamma to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter CR_grad to graph (2026-06-09 10:29:46; Flux.py:126)
# DEBUG:NNMFit.core.weight_builder: Multiplying flux prompt_hese by livetime (414033153.63 seconds) (2026-06-09 10:29:46; weight_builder.py:248)
# INFO:NNMFit.core.weight_builder: Built weight graph for IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:46; weight_builder.py:268)
# INFO:NNMFit.core.histogram_builder: Calculating expectation mu for component astro without explicit oversampling. (2026-06-09 10:29:46; histogram_builder.py:145)
# INFO:NNMFit.core.histogram_builder: Calculating expectation mu for component conventional_hese without explicit oversampling. (2026-06-09 10:29:47; histogram_builder.py:145)
# INFO:NNMFit.core.histogram_builder: Calculating expectation mu for component prompt_hese without explicit oversampling. (2026-06-09 10:29:47; histogram_builder.py:145)
# DEBUG:NNMFit.core.histogram_builder: Collected overall parameters: [] (2026-06-09 10:29:47; histogram_builder.py:377)
# INFO:NNMFit.core.histogram_builder: Built histogram graph for IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:47; histogram_builder.py:410)
# Including data_hists in the output file
# DEBUG:NNMFit.data_handling.data_handler: Reading file /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/data_HESE_pass2/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/dataset_data_HESE_pass2.parquet (2026-06-09 10:29:47; data_handler.py:32)
# DEBUG:NNMFit.data_handling.data_handler: Ignoring all keys except for None (2026-06-09 10:29:47; data_handler.py:33)
# INFO:NNMFit.data_handling.data_handler: Setting analysis vars: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:29:47; data_handler.py:130)
# WARNING:NNMFit.core.mask_handler: Please specify, which masks should be applied by adding 'apply_standard_mask = True/False' to your detector config. For now the mask will be applied, but this default will be deprecated in the future. (2026-06-09 10:29:47; mask_handler.py:65)
# DEBUG:NNMFit.core.mask_handler: Found 177 events in binning (2026-06-09 10:29:47; mask_handler.py:156)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '>', '59979.10762555'] (2026-06-09 10:29:47; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '>', '59979.10762555'], 115 events remain. (2026-06-09 10:29:47; mask_handler.py:249)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '<', '12589254.11794166'] (2026-06-09 10:29:47; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '<', '12589254.11794166'], 115 events remain. (2026-06-09 10:29:47; mask_handler.py:249)
# WARNING:NNMFit.core.mask_handler: 'additional_mask' will be deprecated in the future. Use 'custom_mask' instead (2026-06-09 10:29:47; mask_handler.py:86)
# DEBUG:NNMFit.data_handling.data_handler: Applying mask, new n_events: 107 (2026-06-09 10:29:47; data_handler.py:175)
# Wrote function of histograms to /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_NoSystematics_e1_e2_zoom/Precalculated_Graph.pickle
# Full execution took 6.18 seconds
#
# Generating Data Histogram: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_NoSystematics_e1_e2_zoom/Data_Histogram.pickle
# Called with:
# main_config             : None
# analysis_config         : None
# config_dir              : None
# override_configs        : None
# override_components     : None
# override_parameters     : None
# config_infile           : None
# precalculated_graph     : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_NoSystematics_e1_e2_zoom/Precalculated_Graph.pickle
# outfile                 : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_NoSystematics_e1_e2_zoom/Data_Histogram.pickle
# rnd_seed                : None
# pseudoexp_seed          : None
# init_method             : from_precalculation
# DEBUG:NNMFit.core.loader: Loading the binning and mask for IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:29:52; loader.py:43)
# DEBUG:NNMFit.binning.rectangular_binning: binning variables: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:29:52; rectangular_binning.py:105)
# DEBUG:NNMFit.binning.rectangular_binning: Histogram of det. conf. IC86_pass2_SnowStorm_FTP_HESE_Combined has 2 dimensions  (2026-06-09 10:29:52; rectangular_binning.py:271)
# DEBUG:NNMFit.binning.rectangular_binning: binning variables: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:29:52; rectangular_binning.py:105)
# DEBUG:NNMFit.binning.rectangular_binning: Histogram of det. conf. IC86_pass2_SnowStorm_FTP_HESE_Combined has 2 dimensions  (2026-06-09 10:29:52; rectangular_binning.py:271)
# INFO:NNMFit.core.nnm_fitter: Analysis type set to data (2026-06-09 10:29:52; nnm_fitter.py:87)
# INFO:NNMFit.core.nnm_fitter: Loading the precalculated graph.. (2026-06-09 10:29:52; nnm_fitter.py:92)
# DEBUG:NNMFit.core.nnm_fitter: Using version 3 for precalculating (2026-06-09 10:29:52; nnm_fitter.py:98)
# INFO:NNMFit.core.graph_builder: Using precalculated graphs, will NOT setup WeightBuidler and HistogramBuilder (2026-06-09 10:29:52; graph_builder.py:84)
# INFO:NNMFit.core.graph_builder: Use input vars from precalculated graphs: ['astro_norm', 'gamma_astro', 'conv_norm', 'delta_gamma', 'CR_grad', 'barr_h', 'barr_w', 'barr_z', 'barr_y', 'prompt_norm'] (2026-06-09 10:29:52; graph_builder.py:88)
# INFO:NNMFit.core.nnm_fitter: Loading 'data_hists' from precalculated graph file (2026-06-09 10:29:52; nnm_fitter.py:321)
# Wrote dataset to /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_NoSystematics_e1_e2_zoom/Data_Histogram.pickle
# Full execution took 0.2502298355102539 seconds
# Loading Data Histogram: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_NoSystematics_e1_e2_zoom/Data_Histogram.pickle
# ---------- Separate component Astro
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3_Astro.yaml
# ---------- Separate component Conv
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3_Conv.yaml
# ---------- Separate component Muon
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3_Muon.yaml
#
# Called with:
# main_config             : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/main.cfg
# analysis_config         : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3.yaml
# config_dir              : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/
# override_configs        : ['override/systematics/hese_combined/unblind_bdt/Snowstorm_Gradients_hese_combined_HESEBestfit_SPL_wpriors_e1_e2_zoom.cfg', 'override/livetime/hese_livetime_13yr.cfg', 'override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg', 'override/binning/hese/combined/cut_energy.cfg', 'override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg']
# override_components     : ['override/components/astro_SPL_no_inel_no_flavor.yaml']
# override_parameters     : None
# config_infile           : None
# precalculated_graph     : None
# outfile                 : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_e1_e2_zoom/Precalculated_Graph.pickle
# init_method             : from_configs
#
# INFO:NNMFit.core.analysis_config: Loading main config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/main.cfg (2026-06-09 10:30:00; analysis_config.py:179)
# DEBUG:NNMFit.core.analysis_config: Keys loaded: ['DEFAULT', 'main', 'minimizer_settings'] (2026-06-09 10:30:00; analysis_config.py:181)
# INFO:NNMFit.core.analysis_config: Overriding config with: ['override/systematics/hese_combined/unblind_bdt/Snowstorm_Gradients_hese_combined_HESEBestfit_SPL_wpriors_e1_e2_zoom.cfg', 'override/livetime/hese_livetime_13yr.cfg', 'override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg', 'override/binning/hese/combined/cut_energy.cfg', 'override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg'] (2026-06-09 10:30:00; analysis_config.py:362)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/systematics/hese_combined/unblind_bdt/Snowstorm_Gradients_hese_combined_HESEBestfit_SPL_wpriors_e1_e2_zoom.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/livetime/hese_livetime_13yr.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/binning/hese/combined/cut_energy.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Reading detector configs ['IC86_pass2_SnowStorm_FTP_HESE_Combined'] from dir /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/ (2026-06-09 10:30:00; analysis_config.py:328)
# INFO:NNMFit.core.analysis_config: Reading components settings from: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/components.yaml (2026-06-09 10:30:00; analysis_config.py:253)
# INFO:NNMFit.core.analysis_config: Overriding components settings (2026-06-09 10:30:00; analysis_config.py:257)
# INFO:NNMFit.core.analysis_config: Overriding settings with: override/components/astro_SPL_no_inel_no_flavor.yaml (2026-06-09 10:30:00; analysis_config.py:310)
# INFO:NNMFit.core.analysis_config: Reading parameter settings from: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/parameters.yaml (2026-06-09 10:30:00; analysis_config.py:264)
# DEBUG:NNMFit.core.analysis_config: Reading config for conventional_globalfit component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter conv_norm for conventional_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for conventional_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for conventional_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_h for conventional_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_w for conventional_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_z for conventional_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_y for conventional_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter conv_norm for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_h for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_w for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_z for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_y for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter effective_veto for conventional_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for prompt_globalfit component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter prompt_norm for prompt_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for prompt_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for prompt_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for prompt_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter prompt_norm for prompt_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for prompt_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for prompt_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter effective_veto for prompt_veto_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for muontemplate_cascade_globalfit component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter muongun_norm_cascade for muontemplate_cascade_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for muontemplate_track_globalfit component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter muon_norm for muontemplate_track_globalfit component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for astro component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter astro_norm for astro component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter gamma_astro for astro component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for conventional_hese component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter conv_norm for conventional_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for conventional_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for conventional_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_h for conventional_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_w for conventional_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_z for conventional_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter barr_y for conventional_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for prompt_hese component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter prompt_norm for prompt_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter delta_gamma for prompt_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Adding parameter CR_grad for prompt_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# DEBUG:NNMFit.core.analysis_config: Reading config for muontemplate_hese component (2026-06-09 10:30:00; analysis_config.py:275)
# DEBUG:NNMFit.core.analysis_config: Adding parameter muongun_norm for muontemplate_hese component (2026-06-09 10:30:00; analysis_config.py:282)
# INFO:NNMFit.core.analysis_config: Reading detector systematics config: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/SnowStorm_systematics.cfg (2026-06-09 10:30:00; analysis_config.py:343)
# INFO:NNMFit.core.analysis_config: Overriding config with: ['override/systematics/hese_combined/unblind_bdt/Snowstorm_Gradients_hese_combined_HESEBestfit_SPL_wpriors_e1_e2_zoom.cfg', 'override/livetime/hese_livetime_13yr.cfg', 'override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg', 'override/binning/hese/combined/cut_energy.cfg', 'override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg'] (2026-06-09 10:30:00; analysis_config.py:362)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/systematics/hese_combined/unblind_bdt/Snowstorm_Gradients_hese_combined_HESEBestfit_SPL_wpriors_e1_e2_zoom.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/livetime/hese_livetime_13yr.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/binning/hese/combined/Taupede1_Particles_energy_Taupede2_Particles_energy_10bins_zoom.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/binning/hese/combined/cut_energy.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# INFO:NNMFit.core.analysis_config: Loading config file: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/override/datasets_GP_globalfit/v3/globalfit_hese_clean_globalfit_v3.cfg (2026-06-09 10:30:00; analysis_config.py:367)
# DEBUG:NNMFit.core.loader: Loading the binning and mask for IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; loader.py:43)
# DEBUG:NNMFit.binning.rectangular_binning: binning variables: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:30:00; rectangular_binning.py:105)
# DEBUG:NNMFit.binning.rectangular_binning: Histogram of det. conf. IC86_pass2_SnowStorm_FTP_HESE_Combined has 2 dimensions  (2026-06-09 10:30:00; rectangular_binning.py:271)
# DEBUG:NNMFit.binning.rectangular_binning: binning variables: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:30:00; rectangular_binning.py:105)
# DEBUG:NNMFit.binning.rectangular_binning: Histogram of det. conf. IC86_pass2_SnowStorm_FTP_HESE_Combined has 2 dimensions  (2026-06-09 10:30:00; rectangular_binning.py:271)
# INFO:NNMFit.core.nnm_fitter: Analysis type set to data (2026-06-09 10:30:00; nnm_fitter.py:87)
# INFO:NNMFit.core.parameter_settings: Skipping component(s) : ['muontemplate_cascade_globalfit', 'conventional_globalfit', 'conventional_veto_globalfit', 'prompt_globalfit', 'prompt_veto_globalfit', 'muon', 'muontemplate_track_globalfit', 'muontemplate_hese'] in weight calculation for det conf IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; parameter_settings.py:122)
# DEBUG:NNMFit.core.parameter_settings: Skipping conventional_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping conventional_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_cascade_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_track_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_hese component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:30:00; parameter_settings.py:159)
# WARNING:NNMFit.parameters.delta_gamma: Did not specify a reference energy for DeltaGamma. Are you sure you want to calculate it as median from the baseline weights directly? This might not include PassingFractions or similar corrections and can result in different reference energies usedfor different detector configurations sharing this parameter. (2026-06-09 10:30:00; delta_gamma.py:34)
# WARNING:NNMFit.parameters.delta_gamma: Did not specify a reference energy for DeltaGamma. Are you sure you want to calculate it as median from the baseline weights directly? This might not include PassingFractions or similar corrections and can result in different reference energies usedfor different detector configurations sharing this parameter. (2026-06-09 10:30:00; delta_gamma.py:34)
# INFO:NNMFit.core.loader: Using dataset: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/dataset_IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight.parquet (2026-06-09 10:30:00; loader.py:104)
# DEBUG:NNMFit.data_handling.data_handler: Reading file /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/dataset_IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight.parquet (2026-06-09 10:30:00; data_handler.py:32)
# DEBUG:NNMFit.data_handling.data_handler: Ignoring all keys except for None (2026-06-09 10:30:00; data_handler.py:33)
# INFO:NNMFit.data_handling.data_handler: Setting analysis vars: ['Taupede1_Particles_energy', 'Taupede2_Particles_energy'] (2026-06-09 10:30:01; data_handler.py:130)
# WARNING:NNMFit.core.mask_handler: Please specify, which masks should be applied by adding 'apply_standard_mask = True/False' to your detector config. For now the mask will be applied, but this default will be deprecated in the future. (2026-06-09 10:30:01; mask_handler.py:65)
# DEBUG:NNMFit.core.mask_handler: Found 588203 events in binning (2026-06-09 10:30:01; mask_handler.py:156)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '>', '59979.10762555'] (2026-06-09 10:30:01; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '>', '59979.10762555'], 650915 events remain. (2026-06-09 10:30:01; mask_handler.py:249)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '<', '12589254.11794166'] (2026-06-09 10:30:01; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '<', '12589254.11794166'], 579216 events remain. (2026-06-09 10:30:01; mask_handler.py:249)
# WARNING:NNMFit.core.mask_handler: 'additional_mask' will be deprecated in the future. Use 'custom_mask' instead (2026-06-09 10:30:01; mask_handler.py:86)
# DEBUG:NNMFit.data_handling.data_handler: Applying mask, new n_events: 539743 (2026-06-09 10:30:01; data_handler.py:175)
# ...
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:29; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_cascade_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:29; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_track_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:29; parameter_settings.py:159)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_hese component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:29; parameter_settings.py:159)
# WARNING:NNMFit.parameters.delta_gamma: Did not specify a reference energy for DeltaGamma. Are you sure you want to calculate it as median from the baseline weights directly? This might not include PassingFractions or similar corrections and can result in different reference energies usedfor different detector configurations sharing this parameter. (2026-06-09 10:32:29; delta_gamma.py:34)
# WARNING:NNMFit.parameters.delta_gamma: Did not specify a reference energy for DeltaGamma. Are you sure you want to calculate it as median from the baseline weights directly? This might not include PassingFractions or similar corrections and can result in different reference energies usedfor different detector configurations sharing this parameter. (2026-06-09 10:32:29; delta_gamma.py:34)
# INFO:NNMFit.core.loader: Using dataset: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/dataset_IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight.parquet (2026-06-09 10:32:29; loader.py:104)
# DEBUG:NNMFit.data_handling.data_handler: Reading file /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/dataset_IC86_pass2_SnowStorm_v2_FTP_Baseline_Combined_v7-v1_fluxlessweight.parquet (2026-06-09 10:32:29; data_handler.py:32)
# DEBUG:NNMFit.data_handling.data_handler: Ignoring all keys except for None (2026-06-09 10:32:29; data_handler.py:33)
# INFO:NNMFit.data_handling.data_handler: Setting analysis vars: ['EventGeneratorDC_Thijs_length', 'RecoERatio_EventGeneratorDC_Max'] (2026-06-09 10:32:30; data_handler.py:130)
# WARNING:NNMFit.core.mask_handler: Please specify, which masks should be applied by adding 'apply_standard_mask = True/False' to your detector config. For now the mask will be applied, but this default will be deprecated in the future. (2026-06-09 10:32:30; mask_handler.py:65)
# DEBUG:NNMFit.core.mask_handler: Found 488016 events in binning (2026-06-09 10:32:30; mask_handler.py:156)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '>', '59979.10762555'] (2026-06-09 10:32:30; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '>', '59979.10762555'], 650915 events remain. (2026-06-09 10:32:30; mask_handler.py:249)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '<', '12589254.11794166'] (2026-06-09 10:32:30; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '<', '12589254.11794166'], 579216 events remain. (2026-06-09 10:32:30; mask_handler.py:249)
# WARNING:NNMFit.core.mask_handler: 'additional_mask' will be deprecated in the future. Use 'custom_mask' instead (2026-06-09 10:32:30; mask_handler.py:86)
# DEBUG:NNMFit.data_handling.data_handler: Applying mask, new n_events: 406027 (2026-06-09 10:32:30; data_handler.py:175)
# DEBUG:NNMFit.core.weight_builder: Memory footprint of shared data variables: 0.039326779544353485 (2026-06-09 10:32:30; weight_builder.py:204)
# INFO:NNMFit.core.parameter_settings: Collecting histogram parameters (2026-06-09 10:32:30; parameter_settings.py:55)
# INFO:NNMFit.core.parameter_settings: Skipping component(s) : ['muontemplate_cascade_globalfit', 'conventional_globalfit', 'conventional_veto_globalfit', 'prompt_globalfit', 'prompt_veto_globalfit', 'muon', 'muontemplate_track_globalfit', 'muontemplate_hese'] for det conf IC86_pass2_SnowStorm_FTP_HESE_Combined in histogram parameters (2026-06-09 10:32:30; parameter_settings.py:64)
# DEBUG:NNMFit.core.parameter_settings: Skipping conventional_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:30; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping conventional_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:30; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:30; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping prompt_veto_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:30; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_cascade_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:30; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_track_globalfit component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:30; parameter_settings.py:86)
# DEBUG:NNMFit.core.parameter_settings: Skipping muontemplate_hese component for detector_config IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:30; parameter_settings.py:86)
# INFO:NNMFit.core.histogram_builder: Building histogram graph for IC86_pass2_SnowStorm_FTP_HESE_Combined ... (2026-06-09 10:32:30; histogram_builder.py:407)
# INFO:NNMFit.core.weight_builder: Building weight graph for IC86_pass2_SnowStorm_FTP_HESE_Combined ... (2026-06-09 10:32:30; weight_builder.py:266)
# INFO:NNMFit.core.weight_builder: Creating graph for flux astro (2026-06-09 10:32:30; weight_builder.py:224)
# DEBUG:NNMFit.fluxes.Flux: Added parameter astro_norm to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter gamma_astro to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.core.weight_builder: Multiplying flux astro by livetime (414033153.63 seconds) (2026-06-09 10:32:30; weight_builder.py:248)
# INFO:NNMFit.core.weight_builder: Creating graph for flux conventional_hese (2026-06-09 10:32:30; weight_builder.py:224)
# DEBUG:NNMFit.fluxes.Flux: Added parameter conv_norm to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter delta_gamma to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter CR_grad to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter barr_h to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter barr_w to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter barr_z to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter barr_y to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.core.weight_builder: Multiplying flux conventional_hese by livetime (414033153.63 seconds) (2026-06-09 10:32:30; weight_builder.py:248)
# INFO:NNMFit.core.weight_builder: Creating graph for flux prompt_hese (2026-06-09 10:32:30; weight_builder.py:224)
# DEBUG:NNMFit.fluxes.Flux: Added parameter prompt_norm to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter delta_gamma to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.fluxes.Flux: Added parameter CR_grad to graph (2026-06-09 10:32:30; Flux.py:126)
# DEBUG:NNMFit.core.weight_builder: Multiplying flux prompt_hese by livetime (414033153.63 seconds) (2026-06-09 10:32:30; weight_builder.py:248)
# INFO:NNMFit.core.weight_builder: Built weight graph for IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:30; weight_builder.py:268)
# INFO:NNMFit.core.histogram_builder: Calculating expectation mu for component astro without explicit oversampling. (2026-06-09 10:32:30; histogram_builder.py:145)
# INFO:NNMFit.core.histogram_builder: Calculating expectation mu for component conventional_hese without explicit oversampling. (2026-06-09 10:32:30; histogram_builder.py:145)
# INFO:NNMFit.core.histogram_builder: Calculating expectation mu for component prompt_hese without explicit oversampling. (2026-06-09 10:32:30; histogram_builder.py:145)
# DEBUG:NNMFit.core.histogram_builder: Collected overall parameters: ['Snowstorm_Gradients_hese_combined_HESEBestfit_SPL_wpriors_evtgen_recoeratio_zoom'] (2026-06-09 10:32:31; histogram_builder.py:377)
# DEBUG:NNMFit.parameters.snowstorm.snowstorm_gradient: Loading pre-calculated gradient from file /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/systematics/IC86_pass2_SnowStorm_v2_FTP_Ensemble_hdf-v1/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/unblind_bdt/hese_combined_HESEBestfit_SPL_no_flavor_evtgen_recoeratio_zoom.pickle (2026-06-09 10:32:31; snowstorm_gradient.py:81)
# WARNING:NNMFit.parameters.snowstorm.snowstorm_gradient: Gradients are considered external (from independent MC) (2026-06-09 10:32:31; snowstorm_gradient.py:102)
# WARNING:NNMFit.parameters.snowstorm.snowstorm_gradient: Different datasets used for calculating the gradients and for building the graph! (2026-06-09 10:32:31; snowstorm_gradient.py:428)
# INFO:NNMFit.core.histogram_builder: Built histogram graph for IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:31; histogram_builder.py:410)
# Including data_hists in the output file
# DEBUG:NNMFit.data_handling.data_handler: Reading file /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/datasets/flavor_globalfit/hese/combined_with_bdt/data_HESE_pass2/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/dataset_data_HESE_pass2.parquet (2026-06-09 10:32:31; data_handler.py:32)
# DEBUG:NNMFit.data_handling.data_handler: Ignoring all keys except for None (2026-06-09 10:32:31; data_handler.py:33)
# INFO:NNMFit.data_handling.data_handler: Setting analysis vars: ['EventGeneratorDC_Thijs_length', 'RecoERatio_EventGeneratorDC_Max'] (2026-06-09 10:32:31; data_handler.py:130)
# WARNING:NNMFit.core.mask_handler: Please specify, which masks should be applied by adding 'apply_standard_mask = True/False' to your detector config. For now the mask will be applied, but this default will be deprecated in the future. (2026-06-09 10:32:31; mask_handler.py:65)
# DEBUG:NNMFit.core.mask_handler: Found 143 events in binning (2026-06-09 10:32:31; mask_handler.py:156)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '>', '59979.10762555'] (2026-06-09 10:32:31; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '>', '59979.10762555'], 115 events remain. (2026-06-09 10:32:31; mask_handler.py:249)
# DEBUG:NNMFit.core.mask_handler: Applying mask with settings ['reco_energy', '<', '12589254.11794166'] (2026-06-09 10:32:31; mask_handler.py:190)
# DEBUG:NNMFit.core.mask_handler: After applying cuts from condition: ['reco_energy', '<', '12589254.11794166'], 115 events remain. (2026-06-09 10:32:31; mask_handler.py:249)
# WARNING:NNMFit.core.mask_handler: 'additional_mask' will be deprecated in the future. Use 'custom_mask' instead (2026-06-09 10:32:31; mask_handler.py:86)
# DEBUG:NNMFit.data_handling.data_handler: Applying mask, new n_events: 84 (2026-06-09 10:32:31; data_handler.py:175)
# Wrote function of histograms to /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_evtgen_recoeratio_zoom/Precalculated_Graph.pickle
# Full execution took 1.62 seconds
#
# Generating Data Histogram: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_evtgen_recoeratio_zoom/Data_Histogram.pickle
# Called with:
# main_config             : None
# analysis_config         : None
# config_dir              : None
# override_configs        : None
# override_components     : None
# override_parameters     : None
# config_infile           : None
# precalculated_graph     : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_evtgen_recoeratio_zoom/Precalculated_Graph.pickle
# outfile                 : /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_evtgen_recoeratio_zoom/Data_Histogram.pickle
# rnd_seed                : None
# pseudoexp_seed          : None
# init_method             : from_precalculation
# DEBUG:NNMFit.core.loader: Loading the binning and mask for IC86_pass2_SnowStorm_FTP_HESE_Combined (2026-06-09 10:32:35; loader.py:43)
# DEBUG:NNMFit.binning.rectangular_binning: binning variables: ['EventGeneratorDC_Thijs_length', 'RecoERatio_EventGeneratorDC_Max'] (2026-06-09 10:32:35; rectangular_binning.py:105)
# DEBUG:NNMFit.binning.rectangular_binning: Histogram of det. conf. IC86_pass2_SnowStorm_FTP_HESE_Combined has 2 dimensions  (2026-06-09 10:32:35; rectangular_binning.py:271)
# DEBUG:NNMFit.binning.rectangular_binning: binning variables: ['EventGeneratorDC_Thijs_length', 'RecoERatio_EventGeneratorDC_Max'] (2026-06-09 10:32:35; rectangular_binning.py:105)
# DEBUG:NNMFit.binning.rectangular_binning: Histogram of det. conf. IC86_pass2_SnowStorm_FTP_HESE_Combined has 2 dimensions  (2026-06-09 10:32:35; rectangular_binning.py:271)
# INFO:NNMFit.core.nnm_fitter: Analysis type set to data (2026-06-09 10:32:35; nnm_fitter.py:87)
# INFO:NNMFit.core.nnm_fitter: Loading the precalculated graph.. (2026-06-09 10:32:35; nnm_fitter.py:92)
# DEBUG:NNMFit.core.nnm_fitter: Using version 3 for precalculating (2026-06-09 10:32:35; nnm_fitter.py:98)
# INFO:NNMFit.core.graph_builder: Using precalculated graphs, will NOT setup WeightBuidler and HistogramBuilder (2026-06-09 10:32:35; graph_builder.py:84)
# INFO:NNMFit.core.graph_builder: Use input vars from precalculated graphs: ['astro_norm', 'gamma_astro', 'conv_norm', 'delta_gamma', 'CR_grad', 'barr_h', 'barr_w', 'barr_z', 'barr_y', 'prompt_norm', 'dom_eff', 'ice_abs', 'ice_scat', 'ice_holep0', 'ice_holep1', 'ice_crystal'] (2026-06-09 10:32:35; graph_builder.py:88)
# INFO:NNMFit.core.nnm_fitter: Loading 'data_hists' from precalculated graph file (2026-06-09 10:32:35; nnm_fitter.py:321)
# Wrote dataset to /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_evtgen_recoeratio_zoom/Data_Histogram.pickle
# Full execution took 0.3149838447570801 seconds
# Loading Data Histogram: /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/philipp/step0_2_1/graphs/hese_combined_spectrum_bestfit_13year_round3_evtgen_recoeratio_zoom/Data_Histogram.pickle
# ---------- Separate component Astro
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3_Astro.yaml
# ---------- Separate component Conv
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3_Conv.yaml
# ---------- Separate component Muon
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/analysis_configs/data/debug_unblind/hese_combined_spectrum_bestfit_13year_round3_Muon.yaml
