# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os, sys

THIS_DIR = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/step1_hese_flux"
if THIS_DIR not in sys.path:
    sys.path.insert(0, THIS_DIR)

from plot_configs import (
    PLOTS,
    GROUP_ALL,
    GROUP_SEPARATE_PLOTTING,
    _separate_plots,
)

sys.path.append("/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind")
from plot_functions import load_histograms, make_all_plots
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Configuration
# Set `model` and `selected_keys` before running the cells below.

# %%
# ---- user parameters ----
BASE_GRAPHS_PATH       = os.path.join(THIS_DIR, "graphs")
BASE_SAVE_PATH         = os.path.join(THIS_DIR, "plots")

# Select which plots to produce.
# Use one of the GROUP_* constants or a custom list of keys (see plot_configs.py).
selected_keys = GROUP_ALL
# selected_keys = GROUP_11FEAT_SYST
# selected_keys = GROUP_11FEAT_NOSYST
# selected_keys = GROUP_FINALTOPO_SYST
# selected_keys = GROUP_FINALTOPO_NOSYST
# selected_keys = GROUP_SEPARATE
# selected_keys = GROUP_FEATURE_BDT
# selected_keys = ["11features_plus_rloglmilli_econf_evtgen_bdt1_bdt2"]

# %% [markdown]
# ## Load histograms

# %%
step0_path = BASE_GRAPHS_PATH          # flat structure (all models)
save_path  = BASE_SAVE_PATH
os.makedirs(save_path, exist_ok=True)

active_plots = [p for p in PLOTS if p["key"] in selected_keys]
print(f"{len(active_plots)} plots selected")

histogram_collection = load_histograms(step0_path, PLOTS)
# Out:
# 28 plots selected
# 11features_plus_rloglmilli_econf_evtgen
# 11features_plus_rloglmilli_econf_evtgen_bdt1_bdt2
# 11features_plus_rloglmilli_econf_evtgen_energy_length_analysis
# 11features_plus_rloglmilli_econf_evtgen_len_easym
# 11features_plus_rloglmilli_econf_evtgen_e1_e2
# 11features_plus_rloglmilli_econf_evtgen_e1_e2_zoom
# 11features_plus_rloglmilli_econf_evtgen_mono_energy_zenith
# 11features_plus_rloglmilli_econf_evtgen_mono_delay_qmax
# 11features_plus_rloglmilli_econf_evtgen_mono_delay_qmax_zoom
# 11features_plus_rloglmilli_econf_evtgen_vtxdist_qtot
# 11features_plus_rloglmilli_econf_evtgen_vtxdist_qtot_zoom
# 11features_plus_rloglmilli_econf_evtgen_taumono_econf
# 11features_plus_rloglmilli_econf_evtgen_taumono_econf_zoom
# 11features_plus_rloglmilli_econf_evtgen_tauspe_taumilli
# 11features_plus_rloglmilli_econf_evtgen_tauspe_taumilli_zoom
# 11features_plus_rloglmilli_econf_evtgen_evtgen_recoeratio
# 11features_plus_rloglmilli_econf_evtgen_evtgen_recoeratio_zoom
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/plot_functions.py:53: RuntimeWarning: invalid value encountered in divide
#   weight = np.where(total_non_muon > 0, bins / total_non_muon, 0.0)

# %% [markdown]
# ## Make plots

# %%
make_all_plots(active_plots, histogram_collection, save_path=save_path, show=True)
# Out:
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/plot_functions.py:229: RuntimeWarning: invalid value encountered in divide
#   ratio_err = ratio * np.sqrt((np.sqrt(data_h) / data_h)**2 + (mc_err / mc_h)**2)
