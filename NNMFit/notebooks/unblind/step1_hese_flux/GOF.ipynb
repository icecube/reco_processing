# %%
import sys, os
import pandas as pd

# %%
import sys
sys.path.append("/data/user/nlad/NNMFitStuff")

# %%
from utils.goodness_of_fit import plot_sat_llh_distribution
from utils.pseudoexp_handling import PseudoexpPlotHandler
import utils.goodness_of_fit as gof

# %%
from NNMFit.utilities import PseudoexpHandler

# %%
# data_fit_file = '/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/dag_scans/flavor_globalfit/hese/unblind/step1_hese_flux/data_fits/force_full_3_nlight_20/nbestfit20_scan_astro_gamma_1D_10steps/Freefit_15.pickle'
data_fit_file = '/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/dag_scans/flavor_globalfit/hese/unblind/step1_hese_flux/data_fits/force_full_3_nlight_20/nbestfit20_scan_astro_gamma_1D_10steps_round2/Freefit_17.pickle'

# %%
plot_hdl = PseudoexpPlotHandler()

# %%
pse_path = '/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/dag_scans/flavor_globalfit/hese/unblind/step1_hese_flux/pse'
# minimizer = 'force_full_3_nlight_20'
minimizer = 'LBFGSB'
indir = f'{pse_path}/{minimizer}/pse_hese_spectrum_bestfit_13year_n500_round3'
plot_hdl.add_pseudoexp(
    identifier='HESE-13, batch1',
    hdl=PseudoexpHandler(
        indir=indir,
        force_read=True,
        mask_unsuccessful=True,
    ),
    label='Pseudoexps',
)

# %%
import matplotlib.pyplot as plt
font_title = {'family': 'serif',
                'color':  'black',
                'weight': 'bold',
                'size': 50,
                }

# %%
TS_data_overall = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='say',say_sat_llh_type='poisson')
# Out:
# Likelihood value: 212.8606063267837
# None
# ----------------
# None
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF

# %%
fig, ax1 = plt.subplots(1,1, figsize=(8,6))
ts = plot_hdl.plot_TS(
    title='HESE-12',
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax1,
    
    data_TS=TS_data_overall)

plt.tight_layout()

plt.show()
# Out:
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# ...
