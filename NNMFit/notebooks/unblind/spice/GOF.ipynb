# %%
import sys, os
import pandas as pd

# %%
import sys
sys.path.append("/data/user/nlad/NNMFitStuff")

# %%
from utils.plot_utils import savefig
from utils.goodness_of_fit import plot_sat_llh_distribution
from utils.pseudoexp_handling import PseudoexpPlotHandler

# %%
from utils import goodness_of_fit as gof

# %%
from NNMFit.utilities import PseudoexpHandler

# %%
# indir = '/data/ana/Diffuse/GlobalFit_Flavor/FitResults/Data/HESE12/SPL/SAY/Pseudoexperiments/GOF/WithoutDC/LvsE_largebins/prioronholeice/'
indir = '/data/user/tvaneede/GlobalFit/neha_unblinding/prioronholeice'

# %%
# data_fit_file = '/data/ana/Diffuse/GlobalFit_Flavor/FitResults/Data/HESE12/SPL/SAY/PriorOnConvDeltaInel3Syst_WithNoDCGradients_NODCData/Freefit_07.pickle'
data_fit_file = '/data/ana/Diffuse/GlobalFit_Flavor/FitResults/Data/HESE12_Thesis/Freefit_07.pickle'

# %%
# gof.calculate_TS_datafit?

# %%
plot_hdl = PseudoexpPlotHandler()

# %%
plot_hdl.add_pseudoexp(
    identifier='HESE-12,Without DeepCore',
    hdl=PseudoexpHandler(
        indir=indir,
        force_read=True,
        mask_unsuccessful=True,
    ),
    label='Pseudoexps',
)

# %%
import matplotlib.pyplot as plt
font_title = {'family': 'serif',
                'color':  'black',
                'weight': 'bold',
                'size': 50,
                }

# %%
TS_data_overall = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='say',say_sat_llh_type='poisson')
# Out:
# Likelihood value: 182.97993921665187
# None
# ----------------
# None
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF

# %%
fig, ax1 = plt.subplots(1,1, figsize=(8,6))
ts = plot_hdl.plot_TS(
    title='HESE-12',
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax1,
    
    data_TS=TS_data_overall)

plt.tight_layout()

plt.show()
# Out:
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# Calculating overall GOF
# ...

# %%
TS_data_tracks = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='poisson',say_sat_llh_type='poisson',
                                  det_config='IC86_pass2_SnowStorm_v2_Bfr_Tracks',
                                  calculate_marginalTS=False,
                                  )
TS_data_DC = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='poisson',say_sat_llh_type='poisson',
                                  det_config='IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades',
                                  calculate_marginalTS=False,
                                  )
TS_data_cascades = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='poisson',say_sat_llh_type='poisson',
                                  det_config='IC86_pass2_SnowStorm_v2_Bfr_Cascades',
                                  calculate_marginalTS=False,
                                  )


fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(18,6))
ts_tracks = plot_hdl.plot_TS(
    title='HESE-12',
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax1,
    det_config='IC86_pass2_SnowStorm_v2_Bfr_Tracks',
    data_TS=TS_data_tracks,
    calculate_marginalTS=False,
    subtitle = 'Tracks'
)

ts_cascades = plot_hdl.plot_TS(
    
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax2,
    det_config='IC86_pass2_SnowStorm_v2_Bfr_Cascades',
    data_TS=TS_data_cascades,
    calculate_marginalTS=False,
  
    subtitle = 'Cascades'
)


ts_DC = plot_hdl.plot_TS(
    
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax3,
    det_config='IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades',
    data_TS=TS_data_DC,
    calculate_marginalTS=False,
  
    subtitle = 'Double Cascades'
)

plt.tight_layout()

plt.show()
# Out:
# Likelihood value: 182.97993921665187
# IC86_pass2_SnowStorm_v2_Bfr_Tracks
# ----------------
# IC86_pass2_SnowStorm_v2_Bfr_Tracks
# Likelihood value: 182.97993921665187
# IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades
# ----------------
# IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades
# Likelihood value: 182.97993921665187
# IC86_pass2_SnowStorm_v2_Bfr_Cascades
# ----------------
# IC86_pass2_SnowStorm_v2_Bfr_Cascades
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Tracks
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Tracks
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Tracks
# ---Calculating GOF for detcteor config IC86_pass2_SnowStorm_v2_Bfr_Tracks---
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Tracks
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Tracks
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Tracks
# ...

# %%
TS_data_Cascades_energy = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='say',say_sat_llh_type='poisson',
                                  det_config='IC86_pass2_SnowStorm_v2_Bfr_Cascades',
                                  calculate_marginalTS=True,
                                  marginalTS_variable='reco_energy')

TS_data_Cascades_zenith = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='say',say_sat_llh_type='poisson',
                                  det_config='IC86_pass2_SnowStorm_v2_Bfr_Cascades',
                                  calculate_marginalTS=True,
                                  marginalTS_variable='reco_zenith')

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))
ts_Cascades_energy = plot_hdl.plot_TS(
    title='HESE-12, Cascades Without DeepCore',
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax1,
    det_config='IC86_pass2_SnowStorm_v2_Bfr_Cascades',
    data_TS=TS_data_Cascades_energy,
    calculate_marginalTS=True,
    marginalTS_variable='reco_energy',
    subtitle = 'Cascades energy'
)

ts_Cascades_zenith = plot_hdl.plot_TS(
    
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax2,
    det_config='IC86_pass2_SnowStorm_v2_Bfr_Cascades',
    data_TS=TS_data_Cascades_zenith,
    calculate_marginalTS=True,
    marginalTS_variable='reco_zenith',
    subtitle = 'Cascades - zenith'
)

plt.tight_layout()

plt.show()
# Out:
# Likelihood value: 182.97993921665187
# IC86_pass2_SnowStorm_v2_Bfr_Cascades
# ----------------
# IC86_pass2_SnowStorm_v2_Bfr_Cascades
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Cascades
# 1D marginal GOF requested, for IC86_pass2_SnowStorm_v2_Bfr_Cascades and for variable                                                                  reco_energy
# Calculating GOF for detcteor config IC86_pass2_SnowStorm_v2_Bfr_Cascades for variable reco_energy
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Cascades
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Cascades
# Likelihood value: 182.97993921665187
# IC86_pass2_SnowStorm_v2_Bfr_Cascades
# ----------------
# IC86_pass2_SnowStorm_v2_Bfr_Cascades
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_Cascades
# ...

# %%
TS_data_DoubleCascades_energy = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='say',say_sat_llh_type='poisson',
                                  det_config='IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades',
                                  calculate_marginalTS=True,
                                  marginalTS_variable='reco_energy')

TS_data_DoubleCascades_eratio = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='say',say_sat_llh_type='poisson',
                                  det_config='IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades',
                                  calculate_marginalTS=True,
                                  marginalTS_variable='eratio')

TS_data_DoubleCascades_length = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
                                  llh_type='say',say_sat_llh_type='poisson',
                                  det_config='IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades',
                                  calculate_marginalTS=True,
                                  marginalTS_variable='reco_length')

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(18,6))
ts_DoubleCascades_energy = plot_hdl.plot_TS(
    title='HESE-12, Double Cascades Without DeepCore',
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax1,
    det_config='IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades',
    data_TS=TS_data_DoubleCascades_energy,
    calculate_marginalTS=True,
    marginalTS_variable='reco_energy',
    subtitle = 'Double Cascades Energy'
)

ts_DoubleCascades_eratio = plot_hdl.plot_TS(
    title='HESE-12, Double Cascades Without DeepCore',
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax2,
    det_config='IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades',
    data_TS=TS_data_DoubleCascades_eratio,
    calculate_marginalTS=True,
    marginalTS_variable='eratio',
    subtitle = 'Double Cascades Eratio'
)

ts_DoubleCascades_length = plot_hdl.plot_TS(
    title='HESE-12, Double Cascades Without DeepCore',
    llh_type="say", say_sat_llh_type="poisson",
    ax = ax3,
    det_config='IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades',
    data_TS=TS_data_DoubleCascades_eratio,
    calculate_marginalTS=True,
    marginalTS_variable='reco_length',
    subtitle = 'Double Cascades Length'
)

plt.tight_layout()

plt.show()
# Out:
# Likelihood value: 182.97993921665187
# IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades
# ----------------
# IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades
# per detector config GOF requested,for IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades
# 1D marginal GOF requested, for IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades and for variable                                                                  reco_energy
# Calculating GOF for detcteor config IC86_pass2_SnowStorm_v2_Bfr_DoubleCascades for variable reco_energy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 TS_data_DoubleCascades_energy = gof.calculate_TS_datafit(fit_res_file=data_fit_file,
#       2                                   llh_type='say',say_sat_llh_type='poisson',
# ...

# %%
ts = plot_hdl.plot_TS(
    title='HESE-12,Without DeepCore',
    llh_type="say", say_sat_llh_type="poisson",
    figsize=(10, 6),
    det_config=None,
    data_TS=TS_data
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       1 ts = plot_hdl.plot_TS(
#       2     title='HESE-12,Without DeepCore',
#       3     llh_type="say", say_sat_llh_type="poisson",
#       4     figsize=(10, 6),
#       5     det_config=None,
# ----> 6     data_TS=TS_data
#       7 )
#
# NameError: name 'TS_data' is not defined

# %%
# ts = plot_hdl.plot_TS(
#     title='HESE-12,Without DeepCore',
#     llh_type="say", say_sat_llh_type="poisson",
#     figsize=(10, 6),
#     det_config=None,
#     data_TS=TS_data
# )
