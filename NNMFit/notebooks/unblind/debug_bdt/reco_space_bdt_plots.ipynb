# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os, sys

THIS_DIR = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/unblind/debug_bdt"
if THIS_DIR not in sys.path:
    sys.path.insert(0, THIS_DIR)

from plot_configs import get_plots, GROUP_11FEAT_BDTPROD, GROUP_SEPARATE, GROUP_COMBINED_NOSYST, GROUP_COMBINED_SYST, GROUP_FEATURE_BDT, GROUP_ALL
from plot_functions import load_histograms, make_all_plots
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Configuration
# Set `model` and `selected_keys` before running the cells below.

# %%
# ---- user parameters ----
model = "FinalTopology_double_energy_length_binning"

BASE_GRAPHS_PATH = os.path.join(THIS_DIR, "graphs")
BASE_SAVE_PATH   = os.path.join(THIS_DIR, "plots")

# Select which plots to produce.
# Use one of the GROUP_* constants or a custom list of keys (see plot_configs.py).
# selected_keys = GROUP_ALL
# selected_keys = GROUP_COMBINED_NOSYST
# selected_keys = GROUP_COMBINED_SYST
selected_keys = GROUP_11FEAT_BDTPROD
# selected_keys = ["combined_bdt_scores", "combined_len_easym"]

show_chi2 = False  # set True to annotate plots with chi2/ndf

# %% [markdown]
# ## Load histograms

# %%
step0_path = os.path.join(BASE_GRAPHS_PATH, model)
save_path  = os.path.join(BASE_SAVE_PATH,   model)
os.makedirs(save_path, exist_ok=True)

all_plots    = get_plots(model)
active_plots = [p for p in all_plots if p["key"] in selected_keys]
print(f"{len(active_plots)} plots selected for model '{model}'")

histogram_collection = load_histograms(step0_path, active_plots)
# Out:
# 3 plots selected for model 'FinalTopology_double_energy_length_binning'
# 11features_double_energy_bdtprod_binning

# %% [markdown]
# ## Make plots

# %%
make_all_plots(active_plots, histogram_collection, save_path=save_path, show=True, show_chi2=show_chi2)
