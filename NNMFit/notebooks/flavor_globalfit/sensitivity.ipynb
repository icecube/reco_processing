# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys, os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from NNMFit.utilities import ScanHandler

# import plotting utils
sys.path.append( "/data/user/tvaneede/utils" )
from FlavourScansPlotting import get_contour_points

# import scanning points
from flavor_fracs import *
points = pd.read_pickle('/data/user/tvaneede/GlobalFit/custom_scan_flavor/default_custom_scan_points_flavor.pickle')
flavs = flavor_frac(np.asarray(points['astro_nue_ratio']),np.asarray(points['astro_nutau_ratio']))

# import plotting flavor triangle
sys.path.append( "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks" )
from plot_utils_triangle import *

# dict with all my dag scans
from scan_dict import scan_dir_dict

# %%
plotting_path = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/flavor_globalfit/sensitivity"
os.system(f"mkdir -p {plotting_path}")
# Out:
# 0

# %%
# load the data
drop_unsuccessful = True
scan_dict = {}
data = {}
for name, scan_dir in scan_dir_dict.items():
    print(name)
    scan_dict[name] = ScanHandler(scan_dir,dump=False,drop_unsuccessful=drop_unsuccessful)
    data[name] = {}
    data[name]["ftau_asimov_poisson"],data[name]["fe_asimov_poisson"],data[name]["ft_grid_asimov_poisson"],data[name]["fe_grid_asimov_poisson"],data[name]["ts_grid_asimov_poisson"] = get_contour_points(scan_dict,name)
# Out:
# spice_nosyst
# removed stuff
# hese_oldpid_nosyst
# removed stuff
# hese_oldpid
# removed stuff
# hese_oldpid_combinedBase
# removed stuff
# hese_allfeat_bdtprod_combinedBase
# removed stuff
# hese_allfeat_bdtprod_combinedBase_withSyst
# removed stuff
# gf_zheyang
# removed stuff
# gf_v0
# removed stuff
# gf_v0_noHESE

# %%
# spice_ftp_oldpid_bdtprod
names = [
"spice_nosyst",
"hese_oldpid_nosyst",
"hese_allfeat_bdtprod_combinedBase",
]
labels = [
    "Spice, old reco",
    "FTP, new reco",
    "FTP, BDT",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"$\phi_0 = 2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/spice_ftp_oldpid_bdtprod.png")

for name in names: compare_area( C, alt_key=name, base_key="spice_nosyst", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# Area ratio (spice_nosyst / spice_nosyst) at 68%: 1.0000
# Area ratio (hese_oldpid_nosyst / spice_nosyst) at 68%: 0.7632
# Area ratio (hese_allfeat_bdtprod_combinedBase / spice_nosyst) at 68%: 0.5957

# %%
# spice_ftp_oldpid_bdtprod
names = [
"hese_oldpid_nosyst",
"hese_oldpid_combinedBase",
"hese_allfeat_bdtprod_combinedBase",
"hese_allfeat_bdtprod_combinedBase_withSyst",
]
labels = [
    "No detector systematics",
    "With",
    "No detector systematics",
    "With",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"$\phi_0 = 2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/bdtprod_with_without_syst.png")

for name in names: compare_area( C, alt_key=name, base_key="hese_allfeat_bdtprod_combinedBase", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# Area ratio (hese_oldpid_nosyst / hese_allfeat_bdtprod_combinedBase) at 68%: 1.2704
# Area ratio (hese_oldpid_combinedBase / hese_allfeat_bdtprod_combinedBase) at 68%: 1.2965
# Area ratio (hese_allfeat_bdtprod_combinedBase / hese_allfeat_bdtprod_combinedBase) at 68%: 1.0000
# Area ratio (hese_allfeat_bdtprod_combinedBase_withSyst / hese_allfeat_bdtprod_combinedBase) at 68%: 0.9034
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()

# %%
# gf_zheyang_v0_noHESE
names = [
"gf_zheyang",
"gf_v0",
"gf_v0_noHESE",
]
labels = [
    "GlobalFit Zheyang",
    "GlobalFit",
    "GlobalFit, no HESE",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"$\phi_0 = 1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/gf_zheyang_v0_noHESE.png")

for name in names: compare_area( C, alt_key=name, base_key="gf_zheyang", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# Area ratio (gf_zheyang / gf_zheyang) at 68%: 1.0000
# Area ratio (gf_v0 / gf_zheyang) at 68%: 0.8695
# Area ratio (gf_v0_noHESE / gf_zheyang) at 68%: 1.4185
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()

# %%
# gfh_no_overlap
names = [
"gfh_fluxh_woverlap",
"gfh_fluxh",
]
labels = [
    "GF+H",
    "GF+H, no overlap",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"$\phi_0 = 2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/gfh_fluxh.png")

for name in names: compare_area( C, alt_key=name, base_key="gfh_fluxh_woverlap", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# Area ratio (gfh_fluxh_woverlap / gfh_fluxh_woverlap) at 68%: 1.0000
# Area ratio (gfh_fluxh / gfh_fluxh_woverlap) at 68%: 1.1167

# %%
# gfh_no_overlap
names = [
"gfh_fluxg_woverlap",
"gfh_fluxg",
]
labels = [
    "GF+H",
    "GF+H, no overlap",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"$\phi_0 = 1.8,\gamma=2.52$",
                  savepath = f"{plotting_path}/gfh_fluxg.png")

for name in names: compare_area( C, alt_key=name, base_key="gfh_fluxg_woverlap", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# Area ratio (gfh_fluxg_woverlap / gfh_fluxg_woverlap) at 68%: 1.0000
# Area ratio (gfh_fluxg / gfh_fluxg_woverlap) at 68%: 1.1307

# %%
# spice_ftp_globalfit
names = [
"spice_nosyst",
"hese_allfeat_bdtprod_combinedBase",
"gf_zheyang"
]
labels = [
    "Spice, old reco",
    "FTP, BDT",
    r"Globalfit $\phi_0 = 1.8,\gamma=2.52$",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"$\phi_0 = 2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/spice_ftp_globalfit.png")

for name in names: compare_area( C, alt_key=name, base_key="spice_nosyst", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# Area ratio (spice_nosyst / spice_nosyst) at 68%: 1.0000
# Area ratio (hese_allfeat_bdtprod_combinedBase / spice_nosyst) at 68%: 0.6008
# Area ratio (gf_zheyang / spice_nosyst) at 68%: 0.2431
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()

# %%
# spice_ftp_globalfit_combined
names = [
"spice_nosyst",
"hese_allfeat_bdtprod_combinedBase",
"gf_zheyang",
"gfh_fluxh",
]
labels = [
    "Spice, old reco",
    "FTP, BDT",
    r"Globalfit $\phi_0 = 1.8,\gamma=2.52$",
    r"Combined $\phi_0 = 2.12,\gamma=2.87$",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"$\phi_0 = 2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/spice_ftp_globalfit_combined.png")

for name in names: compare_area( C, alt_key=name, base_key="spice_nosyst", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# Area ratio (spice_nosyst / spice_nosyst) at 68%: 1.0000
# Area ratio (hese_allfeat_bdtprod_combinedBase / spice_nosyst) at 68%: 0.6008
# Area ratio (gf_zheyang / spice_nosyst) at 68%: 0.2477
# Area ratio (gfh_fluxh / spice_nosyst) at 68%: 0.1043
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()

# %%
# spice_ftp_globalfit_combined_fluxhg
names = [
"spice_nosyst",
"hese_allfeat_bdtprod_combinedBase",
"gf_zheyang",
"gfh_fluxh",
"gfh_fluxg",
]
labels = [
    "Spice, old reco",
    "FTP, BDT",
    r"Globalfit $\phi_0 = 1.8,\gamma=2.52$",
    r"Combined $\phi_0 = 2.12,\gamma=2.87$",
    r"Combined $\phi_0 = 1.8,\gamma=2.52$",
]
C = compare_contours( data = data,
                  names = names,
                  labels = labels,
                  levels = ["68%"],
                  title = r"$\phi_0 = 2.12,\gamma=2.87$",
                  savepath = f"{plotting_path}/spice_ftp_globalfit_combined_fluxhg.png")

for name in names: compare_area( C, alt_key=name, base_key="spice_nosyst", levels=["68%"] )
# Out:
# /data/user/tvaneede/utils/Ternary.py:74: UserWarning: First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#   ax.xaxis.grid(*args, **kwargs)
# Area ratio (spice_nosyst / spice_nosyst) at 68%: 1.0000
# Area ratio (hese_allfeat_bdtprod_combinedBase / spice_nosyst) at 68%: 0.6008
# Area ratio (gf_zheyang / spice_nosyst) at 68%: 0.2477
# Area ratio (gfh_fluxh / spice_nosyst) at 68%: 0.1163
# Area ratio (gfh_fluxg / spice_nosyst) at 68%: 0.1257
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
# /data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/plot_utils_triangle.py:92: MatplotlibDeprecationWarning: The collections attribute was deprecated in Matplotlib 3.8 and will be removed in 3.10.
#   paths = contour_obj.collections[i].get_paths()
