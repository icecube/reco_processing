# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LogLocator
import os

# %%
import NNMFit
from NNMFit.utilities.readout_graphs import HistogramGraph
from NNMFit.core.analysis_config import AnalysisConfig

# %%
import sys
sys.path.append("/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks")
from plot_utils import plot_histogram, plot_histogram_astro_flavor, plot_histogram_astro_newflavor

# %%
plotting_path = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/notebooks/compare_globalfit/configs_GP_globalfit"
os.system(f"mkdir -p {plotting_path}")
# Out:
# 0

# %% [markdown]
# First Philipps configs and files

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_SPL.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg"],
        override_components_files=["override/components/astro_SPL_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/GP_globalfit"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"All" : {},
    r"Conventional $\nu$" : {"astro_norm" : 0, "astro_nue_ratio" : 1.0, "astro_nutau_ratio" : 1.0, "gamma_astro" : 2.52, "prompt_norm" : 0, "conv_norm" : 1, "muongun_norm" : 0, "muon_norm" : 0},
    r"Prompt $\nu$" : {"astro_norm" : 0, "astro_nue_ratio" : 1.0, "astro_nutau_ratio" : 1.0, "gamma_astro" : 2.52, "prompt_norm" : 1, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu$" : {"astro_norm" : 1.8, "astro_nue_ratio" : 1.0, "astro_nutau_ratio" : 1.0,"gamma_astro" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Muon" : {"astro_norm" : 0, "astro_nue_ratio" : 1.0, "astro_nutau_ratio" : 1.0,"gamma_astro" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 1, "muon_norm" : 1},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %%
input_variables = {
    r"All" : {"astro_norm" : 1.8, "astro_nue_ratio" : 1.0, "astro_nutau_ratio" : 1.0, "gamma_astro" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"NuMu" : {"astro_norm" : 1.8, "astro_nue_ratio" : 0.0, "astro_nutau_ratio" : 0.0, "gamma_astro" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"NuMu+NuE" : {"astro_norm" : 1.8, "astro_nue_ratio" : 1.0, "astro_nutau_ratio" : 0.0, "gamma_astro" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"NuMu+NuTau" : {"astro_norm" : 1.8, "astro_nue_ratio" : 0.0, "astro_nutau_ratio" : 1.0, "gamma_astro" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                    savepath=f"{plotting_path_histogram}/{det_config}_AstroFlavor_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %% [markdown]
# Lets add my 3 flavor parametrisation

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_SPL.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0

# %%
plotting_path_histogram = f"{plotting_path}/GP_globalfit_3flavor"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 1, "muongun_norm" : 0, "muon_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 1, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Muon" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 1, "muon_norm" : 1},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %%
input_variables = {
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "a" : 1.0, "b" : 1.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "a" : 1.0, "b" : -1.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "a" : 0.0, "b" : 0.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_AstroFlavor_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %% [markdown]
# Lets see if my reproduced cascade works

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_SPL.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg","override/datasets_GP_globalfit/reproduce_cscd_cascade.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0

# %%
plotting_path_histogram = f"{plotting_path}/GP_globalfit_3flavor_reproduce_cscd_cascade"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 1, "muongun_norm" : 0, "muon_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 1, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Muon" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 1, "muon_norm" : 1},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=None)
                #    savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %%
input_variables = {
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "a" : 1.0, "b" : 1.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "a" : 1.0, "b" : -1.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "a" : 0.0, "b" : 0.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=None)
                #    savepath=f"{plotting_path_histogram}/{det_config}_AstroFlavor_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade

# %% [markdown]
# Lets add the double cascade

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_SPL.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg","override/datasets_GP_globalfit/cscd_cascade_double_v0.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0

# %%
plotting_path_histogram = f"{plotting_path}/GP_globalfit_3flavor_cscd_cascade_double_v0"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 1, "muongun_norm" : 0, "muon_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 1, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Muon" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 1, "muon_norm" : 1},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=None)
                #    savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade_double

# %%
input_variables = {
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "a" : 1.0, "b" : 1.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "a" : 1.0, "b" : -1.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "a" : 0.0, "b" : 0.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True,
                   savepath=None) 
                #    savepath=f"{plotting_path_histogram}/{det_config}_AstroFlavor_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade_double

# %% [markdown]
# LEts remove the hese overlap

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit/globalfit_double_SPL.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/systematics/NoSystematics_GP_globalfit.cfg","override/datasets_GP_globalfit/cscd_cascade_double_nohese_v0.cfg"],
        override_components_files=["override/components/astro_SPL_3flavor_no_inel.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()
# Out:
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0
# total_astro_norm a b gamma
# {'total_astro_norm': total_astro_norm, 'a': a, 'b': b, 'gamma': gamma}
# norm: 0.0
# a: 0.0
# b: 0.0
# index: 0.0

# %%
plotting_path_histogram = f"{plotting_path}/GP_globalfit_3flavor_cscd_cascade_double_nohese_v0"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 1, "muongun_norm" : 0, "muon_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 1, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Muon" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 1, "muon_norm" : 1},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade_double

# %%
input_variables = {
    r"Astro $\nu_e$" : {"total_astro_norm" : 1.8, "a" : 1.0, "b" : 1.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\mu$" : {"total_astro_norm" : 1.8, "a" : 1.0, "b" : -1.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu_\tau$" : {"total_astro_norm" : 1.8, "a" : 0.0, "b" : 0.0, "gamma" : 2.52, "prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_AstroFlavor_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade_double

# %% [markdown]
# Lets try to open a combined config

# %%
configs_dir = "/data/user/tvaneede/GlobalFit/reco_processing/NNMFit/configs/flavor_globalfit/"
config_hdl = AnalysisConfig.from_configs(
        main_config_file=f"{configs_dir}/main_globalfit_hese.cfg",
        analysis_config_file = f"{configs_dir}/analysis_configs/asimov/SAY/globalfit_hese/asimov_SAY_GP_globalfit_double_hese_BPL_3flavor.yaml",
        config_dir=configs_dir,
        override_dict=None,
        override_config_files=["override/components/globalfit_hese_BPL_3flavor.cfg",
                                "override/minimizer/minuit.cfg",
                               # globalfit
                                "override/systematics/NoSystematics_GP_globalfit.cfg", 
                               "override/systematics/NoSystematics_hese.cfg",
                               "override/datasets_GP_globalfit/cscd_cascade_double_nohese_v0.cfg",
                               # hese
                               "override/datasets_hese/mcd-simpletopology_flux-hese_feat-11features_plus_rloglmilli_econf_evtgen/bdt1_0.333333_bdt2_0.366667_length_10_fluxlessweight.cfg",
                               "override/binning/hese/10bdtprod_threshold_0.122.cfg",
                               ],
        override_components_files=["override/muon/MuonTemplate_HESE_11features_plus_rloglmilli_econf_evtgen_bdt1_0.333333_bdt2_0.366667.yaml"],
        override_parameters_files=None)
hist_graph_hdl = HistogramGraph(config_hdl)
detector_configs = config_hdl.get_det_configs()

# %%
plotting_path_histogram = f"{plotting_path}/GP_globalfit_hese_3flavor_cscd_cascade_double_nohese_v0"
os.system(f"mkdir -p {plotting_path_histogram}")

input_variables = {
    r"Conventional $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 1, "muongun_norm" : 0, "muon_norm" : 0},
    r"Prompt $\nu$" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 1, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Astro $\nu$" : {"total_astro_norm" : 3*1.8, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 0, "muon_norm" : 0},
    r"Muon" : {"total_astro_norm" : 0, "a" : 0.4444444444, "b" : 0.0, "gamma" : 2.52,"prompt_norm" : 0, "conv_norm" : 0, "muongun_norm" : 1, "muon_norm" : 1},
}

for det_config in detector_configs: 
    plot_histogram(hist_graph_hdl=hist_graph_hdl, det_config=det_config, input_variables = input_variables, ylog=True, 
                   savepath=f"{plotting_path_histogram}/{det_config}_ylog-True.png")
# Out:
# IC86_pass2_SnowStorm_v2_tracks
# IC86_pass2_SnowStorm_v2_cscd_muon
# IC86_pass2_SnowStorm_v2_cscd_hybrid
# IC86_pass2_SnowStorm_v2_cscd_cascade
# IC86_pass2_SnowStorm_v2_cscd_cascade_double
# IC86_pass2_SnowStorm_FTP_HESE_Cascades
# IC86_pass2_SnowStorm_FTP_HESE_DoubleCascades
# IC86_pass2_SnowStorm_FTP_HESE_Tracks
